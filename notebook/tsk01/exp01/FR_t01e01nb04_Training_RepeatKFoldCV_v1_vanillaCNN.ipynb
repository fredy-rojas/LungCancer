# %% [markdown]
# ## About This notebook

# %% [markdown]
# - Prototyping:
#     - Pytorch custom funtions for creating pytorch dataset, train_set(), test_set()
#     - Custom mechanism to track and store DL experiment (id, whole DL pipe params, Model estimates results)
#     - Custom StrategiedKFold, consider the size of the class and respect order_id.
#
# - Objective
# to check if a vanilla CNN architecture can achieve similar high performance that previous paper using more advance architectures.
#
# **Hypothesis:**
# - Several studies have used the dataset with a traditional train-test split that shuffles images. This can lead to data leakage. If such leakage occurs, even simple architectures may achieve high performance. However, the dataset appears to include an order ID, and nearby images tend to have higher correlation. Therefore, if the train-test split preserves the order, it is more likely that images from the same patient will not be mixed, which typically results in lower performance when using the same vanilla architecture.

# %% [markdown]
# **Configurations:**
# - "Config Section"
#     - class cfg will has
#         - this notebook id,
#         - root dataset that will be used in with this code
#         - Where to save experiment results.
#
#
# ______________
# - Training >> Training Configuration section
#     - dicitionary: ppe_params will contains the hyperparameter use for this dl pipeline exp
#     - pipe_params['split_strategy']['shuffle_instances'] True for leakage, False for split considering img order id
#
# **IMPORTANT**
# - Manually setting of experiment tracking id in section Training >> Training Configuration
#     - If you done update this tracking id, your second run will overwrite the previous results.

# %% [markdown]
# ## Import library

# %%
import os
import random
# report more detail errors 
os.environ["TORCH_USE_CUDA_DSA"] = "1"

import gc
import glob
import pickle
from pathlib import Path, PureWindowsPath

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import recall_score
from sklearn.metrics import balanced_accuracy_score

import cv2

import torch

from torch.utils.data import Dataset 
from torch.utils.data import DataLoader

import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

# # if there is error related to CUDA could be related to asynchronous 
# # to force synchronous run this, (it could result in slower operations)
# os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %%
# device = 'cpu'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Config

# %%
class cfg: 
    #==================================================
    # THIS NOTEBOOK ID
    THIS_NOTEBOOK_REF = "FR_t01e01nb04v1" # RepeatedCV

    preprocessing_pipe = 'pipe003'
    meta_csv_preprocessing_pipe = f"FR_t01e01nb02v3_metadata_pipe003.csv"

    #==================================================
    # ROOT PIPE
    ROOT_PIPE = os.path.join('..', '..', '..',
                             'data',
                             preprocessing_pipe,
                            )


    METADATA_PIPE = os.path.join('..', '..', '..',
                                 'data',
                                 preprocessing_pipe,
                                 meta_csv_preprocessing_pipe,
                                )
    
    #==================================================
    # TO STORE RESULTS
    ROOT_TO_SAVE_RESLT = os.path.join('..', '..', '..',
                                      "results",
                                      "exp_track"
                                     )
    os.makedirs(ROOT_TO_SAVE_RESLT, exist_ok=True)

# %% [markdown]
# ## Utility function

# %% [markdown]
# ### custom_StratifiedKFold()

# %%
def custom_StratifiedKFold(d_meta, n_splits=5, 
                            cls_col="cls_id", 
                            inst_n_order_col="img_n_order", 
                            shuffle_instances=False, 
                            random_state=42,
                           ):
    
    """
    Description:
    ------------
        sklearn StratifiedKFold does not keep order. This is a custom function
            to has an option to stratify will keeping the order of the images. 
    
    Paramters:
    ----------
        n_splits: number of folds. "5: 20% each fold"
        cls_col: name of the column in metadata dataframe that indicates classes
        inst_n_order_col: name of column that indicate original order of the instances.
        shuffle_instances: True or False.
        random_state: random seed to obtain always the same instances per fold. 
        
        
    Return:
    -------
        folds: list of lists. Each inner list holds the list of img_ID that belong to the fold. 
                - Structure: [ list_of_img_ids_fold0, ..., list_of_img_ids_fold_n]
    
    
    """
    #============================================================================================
    d = d_meta.copy()
    #============================================================================================
    # Stratify Kfold per class - Custom solution to keep original order. 
    store_fold_per_class = []
    for label in d[cls_col].unique():

        if shuffle_instances: 

            # Select img class >> extract list of unique img_ID >> split list in n_split
            c1 = d[cls_col] == label
            d1 = d[c1].sample(frac=1, random_state=random_state).reset_index(drop=True)
            folds_per_class = np.array_split(d1["img_ID"].to_list(), n_splits)

            store_fold_per_class.append(folds_per_class)

        else: # False: keep img original order
            
            # Select img class >> **sort** & extract list of unique img_ID >> split list in n_split
            c1 = d[cls_col] == label
            d1 = d[c1].sort_values(by=[inst_n_order_col], ascending=True).reset_index(drop=True)
    
            #--------------
            # Rotation and then split 
            img_id_in_order = d1["img_ID"].to_list()
            n = len(img_id_in_order)
            
            rng = random.Random(random_state)
            start_idx = rng.randint(0, n - 1)
    
            rotated = img_id_in_order[start_idx:] + img_id_in_order[:start_idx]
    
            # Split keeping order
            folds_per_class = np.array_split(rotated, n_splits) # out folds_per_class = [[imgIds fold0], ..., [imgIds fold_n]]
    
            store_fold_per_class.append(folds_per_class) # out [folds_per_class 0, ..., folds_per_class m_class]

        #____________________________________________________
        # break

    #============================================================================================
    # unpack store_fold_per_class and concat fold wise each class element.
    folds = []
    for cls_fold_imgs in zip(*store_fold_per_class):
        concat_fold_imgs = np.hstack(cls_fold_imgs)
        folds.append(concat_fold_imgs)
        #____________________________________________________
        # break
    #============================================================================================
    
    return folds

# %% [markdown]
# ### train_step()

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               #loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               arch_id,
               weights,
               epoch_n,
              ): 
    
    #-------------------------------------------------------
    train_loss = 0
    probs_lst = []
    preds_lst = []
    img_id_lst = []
    y_true_lst = []
    loss_lst = []
    for batch, (arr_img, y_true, img_id) in enumerate(dataloader):
        
        #___________________________________________________________
        X, y = arr_img.to(device), y_true.to(device)
        
        w = torch.tensor(list(weights.values()), dtype=torch.float32).to(device)
        
        #___________________________________________________________
        raw_logits = model(X.float())
        
        
        loss_fn = nn.CrossEntropyLoss(weight=w, reduction='none')
        losses = loss_fn(raw_logits, y)
        total_loss = losses.mean()
        train_loss += total_loss.item()
        
        #___________________________________________________________
        optimizer.zero_grad()
    
        total_loss.backward()
        
        optimizer.step()
        
        #__________________________________________________________
        # Store training values
        probs = torch.softmax(raw_logits, dim=1)
        preds = torch.argmax(probs, dim=1) 
        probs_lst.append(probs.cpu().detach().numpy().squeeze())
        preds_lst += list(preds.cpu().detach().numpy().squeeze())
        img_id_lst += list(img_id)
        y_true_lst += y_true.tolist()
        loss_lst += list(losses.cpu().detach().numpy().squeeze())
        
        #__________________________________________________________
        # break
    #--------------------------------------------------------------
    # Extract this training epoch results. 

    trn_loss = train_loss / (batch+1) #len(dataloader)
    
    probs_per_cls = np.vstack(probs_lst)
    d_reslts = pd.DataFrame(probs_per_cls, columns=['0','1','2',])
    d_reslts["y_pred"] = preds_lst
    d_reslts["y_true"] = y_true_lst
    d_reslts['weight'] = d_reslts['y_true'].map(weights) # Weight per class| subject level info not avaialble.
    d_reslts["loss"] = loss_lst
    d_reslts["epoch_n"] = epoch_n
    d_reslts["img_ID"] = img_id_lst
    d_reslts["arch_ID"] = arch_id
    d_reslts["trn_tst"] = "trn"

    acc_trn = accuracy_score(d_reslts["y_true"], d_reslts["y_pred"], sample_weight=d_reslts["weight"])

    #---------------------------------------------
    return trn_loss, acc_trn, d_reslts

# %% [markdown]
# ### test_step()

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              arch_id="vanilla2DCNN_v1", 
              epoch_n=0):
    
    tst_loss = 0
    probs_lst = []
    preds_lst = []
    img_id_lst = []
    y_true_lst = []
    loss_lst = []

    #________________________________________________________________
    with torch.inference_mode():
    
        # Loop through DataLoader batches
        for batch, (arr_img, y_true, img_id) in enumerate(dataloader):
            #___________________________________________________________
            X, y = arr_img.to(device), y_true.to(device)
            #___________________________________________________________
            raw_logits = model(X.float())
            
            
            loss_fn = nn.CrossEntropyLoss(weight=None, reduction='none')
            losses = loss_fn(raw_logits, y)
            total_loss = losses.mean()
            tst_loss += total_loss.item()
        
            #__________________________________________________________
            # Store training values
            probs = torch.softmax(raw_logits, dim=1)
            preds = torch.argmax(probs, dim=1) 
            probs_lst.append(probs.cpu().detach().numpy().squeeze())
            preds_lst += list(preds.cpu().detach().numpy().squeeze())
            img_id_lst += list(img_id)
            y_true_lst += y_true.tolist()
            loss_lst += list(losses.cpu().detach().numpy().squeeze())
        
            #__________________________________________________________
        
            # break
    #--------------------------------------------------------------
    # Extract this training epoch results. 
    
    tst_loss = tst_loss / (batch+1) #len(dataloader)
    
    probs_per_cls = np.vstack(probs_lst)
    d_reslts = pd.DataFrame(probs_per_cls, columns=['0','1','2',])
    d_reslts["y_pred"] = preds_lst
    d_reslts["y_true"] = y_true_lst
    d_reslts['weight'] = d_reslts['y_true'].map(weights) # Weight per class| subject level info not avaialble.
    d_reslts["loss"] = loss_lst
    d_reslts["epoch_n"] = epoch_n
    d_reslts["img_ID"] = img_id_lst
    d_reslts["arch_ID"] = arch_id
    d_reslts["trn_tst"] = "tst"
    
    acc_tst = accuracy_score(d_reslts["y_true"], d_reslts["y_pred"], sample_weight=d_reslts["weight"])

    #----------------------------------------------------------------
    return tst_loss, acc_tst, d_reslts

# %% [markdown]
# ### train()

# %%
def train(model,
          trn_loader,
          tst_loader,
          optimizer,
          weights,
          epochs,
          arch_id,
          foldID,
          track_train_id,
          to_save_root=cfg.ROOT_TO_SAVE_RESLT,
          verbose_epo_steps=1,
          save_model=True,
         ): 



    #____________________________________________________________________
    prcsn_trn_lst = []
    f1score_trn_lst = []
    rec_trn_lst = []
    ba_trn_lst = []
    acc_trn_lst = []
    loss_trn_lst = []
    
    prcsn_tst_lst = []
    f1score_tst_lst = []
    rec_tst_lst = []
    ba_tst_lst = []
    acc_tst_lst = []
    loss_tst_lst = []
    
    lr_lst = []
    epoch_ = -1
    
    #_____________________________________________________________________
    for epoch in range(epochs): 
    
        trn_loss, trn_acc, trn_rslts = train_step(model=model,
                                                  dataloader=trn_loader,
                                                  optimizer=optimizer,
                                                  weights=weights,
                                                  arch_id=arch_id,
                                                  epoch_n=epoch
                                                 )
        trn_rslts["train_trackID"] = track_train_id
        
        tst_loss, tst_acc, tst_rslts = test_step(model=model,
                                                 dataloader=tst_loader,
                                                 arch_id=arch_id,
                                                 epoch_n=epoch)
        tst_rslts["train_trackID"] = track_train_id
        
        #-----------------------------------------------------------------
        #_____________________________________________________________
        # Train metrics 
        prcsn_trn = precision_score(trn_rslts['y_true'], trn_rslts['y_pred'], average='macro', zero_division=0.0)
        f1score_trn = f1_score(trn_rslts['y_true'], trn_rslts['y_pred'], average='macro', zero_division=0.0)
        rec_trn = recall_score(trn_rslts['y_true'], trn_rslts['y_pred'], average='macro', zero_division=0.0)
        ba_trn = balanced_accuracy_score(trn_rslts['y_true'], trn_rslts['y_pred'], adjusted=True)
        acc_trn = accuracy_score(trn_rslts['y_true'], trn_rslts['y_pred'])
        loss_trn = trn_rslts['loss'].mean()
    
        #_____________________________________________________________
        # Test metrics 
        prcsn_tst = precision_score(tst_rslts['y_true'], tst_rslts['y_pred'], average='macro', zero_division=0.0)
        f1score_tst = f1_score(tst_rslts['y_true'], tst_rslts['y_pred'], average='macro', zero_division=0.0)
        rec_tst = recall_score(tst_rslts['y_true'], tst_rslts['y_pred'], average='macro', zero_division=0.0)
        ba_tst = balanced_accuracy_score(tst_rslts['y_true'], tst_rslts['y_pred'], adjusted=True)
        acc_tst = accuracy_score(tst_rslts['y_true'], tst_rslts['y_pred'])
        loss_tst = tst_rslts['loss'].mean()
    
    
        #_____________________________________________________________
        # Storage
        prcsn_trn_lst.append(prcsn_trn)
        f1score_trn_lst.append(f1score_trn)
        rec_trn_lst.append(rec_trn)
        ba_trn_lst.append(ba_trn)
        acc_trn_lst.append(acc_trn)
        loss_trn_lst.append(loss_trn)
    
        prcsn_tst_lst.append(prcsn_tst)
        f1score_tst_lst.append(f1score_tst)
        rec_tst_lst.append(rec_tst)
        ba_tst_lst.append(ba_tst)
        acc_tst_lst.append(acc_tst)
        loss_tst_lst.append(loss_tst)
    
        lr_lst.append(optimizer.param_groups[0]['lr'])
    
        #_____________________________________________________________
        if (epoch%verbose_epo_steps == 0) or (epoch==epochs-1): 
    
            print(
                f"Epo: {epoch} | "
                f"tr_loss: {loss_trn:.4f} | "
                f"tr_acc: {acc_trn:.4f} | "
                f"tst_loss: {loss_tst:.4f} | "
                f"tst_acc: {acc_tst:.4f} |"
                f"tst_ba: {ba_tst:.4f} |"
        
                f"tst_f1: {f1score_tst:.4f} |"
                f"tst_pr: {prcsn_tst:.4f} |"
                f"tst_rc: {rec_tst:.4f} |"
                f"lr: {optimizer.param_groups[0]['lr']:.6f} |"
                )
        
        #_____________________________________________________________
        # After each loop, update performance tracking in case system falls
        perf_dct = {'prcsn_trn':prcsn_trn_lst,
                    'f1score_trn':f1score_trn_lst,
                    'rec_trn':rec_trn_lst,
                    'ba_trn':ba_trn_lst,
                    'acc_trn':acc_trn_lst,
                    'loss_trn':loss_trn_lst,
                    
                    'prcsn_tst':prcsn_tst_lst,
                    'f1score_tst':f1score_tst_lst,
                    'rec_tst':rec_tst_lst,
                    'ba_tst':ba_tst_lst,
                    'acc_tst':acc_tst_lst,
                    'loss_tst':loss_tst_lst,
                    
                    'lr': "df", #lr_lst,
                    'track_train_id':track_train_id,
                    'fold_id':foldID, 
                    'arch_id':arch_id,
                   }
    
        #-----
        # Creating folders to store performace per epoch and SAVE
        root_perfom_across_epo = os.path.join(to_save_root,
                                              track_train_id,
                                              'perform_acrss_epo', #<<<<<<<<
                                              foldID)
        os.makedirs(root_perfom_across_epo, exist_ok=True)
        pickle_fname = f"performance_across_Epochs.pkl"
        fpath = os.path.join(root_perfom_across_epo, pickle_fname)
        with open(fpath, 'wb') as fp:
            pickle.dump(perf_dct, fp)
    
        #_____________________________________________________________
        # Saving predictions of last epochs. 
        m_path = os.path.join(to_save_root, track_train_id, "predictions", foldID)
        os.makedirs(m_path, exist_ok=True)
    
        fpath = os.path.join(m_path, "train_result.csv")
        trn_rslts.to_csv(fpath, index=False)
    
        fpath = os.path.join(m_path, "test_result.csv")
        tst_rslts.to_csv(fpath, index=False)

        #_____________________________________________________________
        # Saving model weights of last training epoch.
        m_path = os.path.join(to_save_root, track_train_id, "models", foldID)
        os.makedirs(m_path, exist_ok=True)

        if save_model:
            model_path = os.path.join(m_path, f"{cfg.THIS_NOTEBOOK_REF}_{foldID}_epo_{epoch}_{track_train_id}_.pth")
            if epoch > epoch_:
                model_path_previous = os.path.join(m_path, f"{cfg.THIS_NOTEBOOK_REF}_{foldID}_epo_{epoch_}_{track_train_id}_.pth")
                if os.path.isfile(model_path_previous):
                    os.remove(model_path_previous) 
    
            torch.save(model.state_dict(), model_path)
            
        
        #_____________________________________________________________
        epoch_ = epoch
        #_____________________________________________________________
        # break
    #_____________________________________________________________


    return trn_rslts, tst_rslts

# %% [markdown]
# ## READ META PIPE

# %%
fpath = cfg.METADATA_PIPE
fpath
# Out:
# '../../../data/pipe003/FR_t01e01nb02v3_metadata_pipe003.csv'

# %%
pipe_meta = pd.read_csv(fpath)
pipe_meta.rename(columns={f'path_img_{cfg.preprocessing_pipe}':'path_img_pipe'}, inplace=True)
pipe_meta.info()
pipe_meta.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097 entries, 0 to 1096
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   path_original_img   1097 non-null   object
#  1   img_ID              1097 non-null   object
#  2   path_img_pipe       1097 non-null   object
#  3   img_shape_original  1097 non-null   object
#  4   img_shape_pipe003   1097 non-null   object
#  5   img_n_order         1097 non-null   int64
#  6   cls_name            1097 non-null   object
#  7   cls_id              1097 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 68.7+ KB
#                                    path_original_img       img_ID  \
# 0  ../../../data/01_original/IQ_OTHNCCD_LungCance...  cls0_order1
# 1  ../../../data/01_original/IQ_OTHNCCD_LungCance...  cls0_order2
# 2  ../../../data/01_original/IQ_OTHNCCD_LungCance...  cls0_order3
# 3  ../../../data/01_original/IQ_OTHNCCD_LungCance...  cls0_order4
# 4  ../../../data/01_original/IQ_OTHNCCD_LungCance...  cls0_order5
#
#                                        path_img_pipe img_shape_original  \
# 0  ../../../data/pipe003/pipe003_imgs/Normal case...            512x512
# 1  ../../../data/pipe003/pipe003_imgs/Normal case...            512x512
# 2  ../../../data/pipe003/pipe003_imgs/Normal case...            512x512
# 3  ../../../data/pipe003/pipe003_imgs/Normal case...            512x512
# 4  ../../../data/pipe003/pipe003_imgs/Normal case...            512x512
#
#   img_shape_pipe003  img_n_order      cls_name  cls_id
# 0           256x256            1  Normal cases       0
# 1           256x256            2  Normal cases       0
# 2           256x256            3  Normal cases       0
# 3           256x256            4  Normal cases       0
# 4           256x256            5  Normal cases       0

# %%
pipe_meta["cls_id"].value_counts()
# Out:
# cls_id
# 2    561
# 0    416
# 1    120
# Name: count, dtype: int64

# %%
# load a image 
img_ID = "cls0_order1"

c1 = pipe_meta["img_ID"] == img_ID
arr_img_path = Path(PureWindowsPath(pipe_meta[c1][f"path_img_pipe"].item()))
arr_img = np.load(arr_img_path)

plt.figure(figsize=(8,8))
plt.imshow(arr_img, cmap='gray', 
           # vmin=0, vmax=255
           # vmin=0, vmax=1
          )
plt.colorbar()
plt.title(f"img_ID: {img_ID}")
plt.show()

# %%
arr_img_path
# Out:
# PosixPath('../../../data/pipe003/pipe003_imgs/Normal cases/pipe003_cls0_order1_.npy')

# %% [markdown]
# ## Custom Pytorch Dataset

# %%
# Creating dataset class
from typing import Tuple, Dict, List


class customPytorchDatset(Dataset):
    
    def __init__(self, d_meta):
        self.d_meta = d_meta

    def __len__(self) -> int: 
        "Returns the total number of samples."
        return len(self.d_meta)

    def __getitem__(self, index):
        fpath = Path(PureWindowsPath(self.d_meta["path_img_pipe"][index]))
        arr_img = np.load(fpath)
        arr_img = np.expand_dims(arr_img, axis=0) #
        arr_img = torch.tensor(arr_img)

        y_true = self.d_meta["cls_id"][index]
        y_true = torch.tensor(y_true, dtype=torch.int64)
        
        img_id = self.d_meta["img_ID"][index]

        
        return arr_img, y_true, img_id

# %%
arr_img, y_true, img_id = next(iter(customPytorchDatset(d_meta = pipe_meta)))
arr_img, y_true, img_id
# Out:
# (tensor([[[0.1725, 0.1725, 0.1725,  ..., 0.1725, 0.1725, 0.1725],
#           [0.1725, 0.1725, 0.1725,  ..., 0.1725, 0.1725, 0.1725],
#           [0.1725, 0.1725, 0.1725,  ..., 0.1725, 0.1725, 0.1725],
#           ...,
#           [0.1725, 0.1725, 0.1725,  ..., 0.1725, 0.1725, 0.1725],
#           [0.1725, 0.1725, 0.1725,  ..., 0.1725, 0.1725, 0.1725],
#           [0.1725, 0.1725, 0.1725,  ..., 0.1725, 0.1725, 0.1725]]],
#         dtype=torch.float64),
#  tensor(0),
#  'cls0_order1')

# %%
arr_img.shape
# Out:
# torch.Size([1, 256, 256])

# %%
        # y = y_true.to(torch.int64)
        # arr_img = torch.tensor(arr_img, dtype=torch.uint8)

# %%
# torch.tensor(arr_img, dtype=torch.uint8)

# %%
# torch.tensor(y_true, dtype=torch.int64)

# %%
# arr_img, y_true, img_id = next(iter(trn_loader))

# %%
plt.imshow(arr_img.numpy()[0].squeeze())
plt.colorbar()
plt.show()

# %% [markdown]
# ## Arch01

# %%
class vanilla2DCNN_v1(nn.Module):
    def __init__(self,
                 in_channels,
                 num_classes,
                ):
        super(vanilla2DCNN_v1, self).__init__()
        
        # Input layer
        self.conv1 = nn.Conv2d(in_channels=in_channels, 
                               out_channels=16, 
                               kernel_size=3, 
                               stride=1, 
                               padding=1)  #  out shape (16, 256, 256)
        
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # out shape (16, 128, 128)
        
        self.conv2 = nn.Conv2d(in_channels=16, 
                               out_channels=32, 
                               kernel_size=3, 
                               stride=1, 
                               padding=1)  # out shape (32, 128, 128)
        
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)  # out shape (32, 64, 64)
        
        # Flatten to feed into FC layer: 32 * 64 * 64
        self.fc1 = nn.Linear(in_features=32 * 64 * 64, 
                             out_features=num_classes)  
        
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)

        x = F.relu(self.conv2(x))
        x = self.pool2(x)

        x = x.view(x.size(0), -1)  # Flatten
        logits = self.fc1(x)
        return logits  # raw scores (logits)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Training configuration

# %%
cfg.preprocessing_pipe
# Out:
# 'pipe003'

# %%
Training_trackID = f"TrainTrack_034" #"TrainTrack_" + "ID"  #<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<< CAREFUL with OVERWRITE

pipe_params = {'prepro_pipe': {'pipe_name':cfg.preprocessing_pipe, # each a transformation step is modified, id changes.
                               'source_code': 'FR_t01e01nb02v4',
                              }, 
               'architecture':{'arch_ID':'vanilla2DCNN_v1', # each arch is modified, id changes.
                               'params': {'in_channels':1,
                                          'num_classes':3,
                                         },
                               'source_code': cfg.THIS_NOTEBOOK_REF
                              },
               'split_strategy': {'split_strategy_id':'splt_strategy_004', # each one parameter change, id changes.
                                  'cv': 'custom_StratifiedKFold()',
                                  'n_split':5,
                                  'cls_col':"cls_id",
                                  'inst_n_order_col':"img_n_order",
                                  'shuffle_instances':False,
                                  'seed':[0,100],
                                  'comment': 'seed [start:end]: Repeated_KfoldCV | shuffle_instances=True generates leakage',
                                 },
               'training_step': {'TrackID': Training_trackID,
                                 'training_strategy_id':'trn_strategy_001', # each one parameter change, id changes.
                                 'source_code':cfg.THIS_NOTEBOOK_REF,
                                 'batch_size':50,
                                 'epochs':10,
                                 'lr':0.001,
                                 'loss_fn':'CrossEntropyLoss',
                                 'balance_strategy': "class weight in loss_fn",
                                 'optimizer': 'Adam',
                                 'verbose_epo_steps':5,
                                 'save_model':False,
                                },
               "general_comments": "", 
              }
#==============================================================================
to_save_root = cfg.ROOT_TO_SAVE_RESLT
track_train_id = pipe_params['training_step']['TrackID']

#----------------------------------------------------------
# creating folder to store ML pipeline params
root_perfom_across_epo = os.path.join(to_save_root,
                                      track_train_id,
                                      'ML_pipe_params',)
os.makedirs(root_perfom_across_epo, exist_ok=True)

#----------------------------------------------------------
# Saving ML pipeline params
pickle_fname = f"ML_pipe_all_params_{Training_trackID}.pkl"
fpath = os.path.join(root_perfom_across_epo, pickle_fname)
with open(fpath, 'wb') as fp:
    pickle.dump(pipe_params, fp)

# %% [markdown]
# ### Stratify KFold

# %%
# validation_imgID_folds = custom_StratifiedKFold(d_meta=pipe_meta,
#                                                 n_splits=pipe_params['split_strategy']['n_split'],
#                                                 cls_col=pipe_params['split_strategy']['cls_col'],
#                                                 inst_n_order_col=pipe_params['split_strategy']['inst_n_order_col'],
#                                                 shuffle_instances=pipe_params['split_strategy']['shuffle_instances'],
#                                                 random_state=pipe_params['split_strategy']['seed'],
#                                                )
# #====================================
# print(f"Check number of images per fold:")
# for f in validation_imgID_folds:
#     print(f"  Count of unique IDs per folds : {np.unique(f).shape} | {f.shape} ")
# print(f" Total of img_ids: {np.hstack(validation_imgID_folds).shape}")

# %% [markdown]
# ### Training steps

# %%
# %%time
in_channels    = pipe_params['architecture']['params']['in_channels']
num_classes    = pipe_params['architecture']['params']['num_classes']
arch_id        = pipe_params['architecture']['arch_ID']

first_seed= pipe_params['split_strategy']['seed'][0]
second_seed= pipe_params['split_strategy']['seed'][1]

epochs         = pipe_params['training_step']['epochs']
batch_size     = pipe_params['training_step']['batch_size']
lr             = pipe_params['training_step']['lr']
track_train_id = pipe_params['training_step']['TrackID']
save_model     = pipe_params['training_step']['save_model']
verbose        = pipe_params['training_step']['verbose_epo_steps']


for seed in range(first_seed,second_seed):

    print(f"_____________________________\nTraining for seed: {seed}")
    
    validation_imgID_folds = custom_StratifiedKFold(d_meta=pipe_meta,
                                                    n_splits=pipe_params['split_strategy']['n_split'],
                                                    cls_col=pipe_params['split_strategy']['cls_col'],
                                                    inst_n_order_col=pipe_params['split_strategy']['inst_n_order_col'],
                                                    shuffle_instances=pipe_params['split_strategy']['shuffle_instances'],
                                                    random_state=seed,
                                                   )

    for fold_n, imgIDs_fold in enumerate(validation_imgID_folds):
    
        foldID = f"seed{seed}_fold{fold_n}"
        
        #_________________________________________________________________
        # Split train and test dataset.
        c_tst = pipe_meta["img_ID"].isin(imgIDs_fold)
        d_tst = pipe_meta[c_tst].reset_index(drop=True)
        
        d_trn = pipe_meta[~c_tst].reset_index(drop=True)
        
        #_________________________________________________________________
        # Extracting weights for each class 
        class_counts = d_trn["cls_id"].value_counts().sort_index()
        N = class_counts.sum()
        K = len(class_counts)
        weights_ = N / (K * class_counts)
        weights = weights_.to_dict()
        
        #_________________________________________________________________
        # Custom pytorch dataset    
        trn_dataset = customPytorchDatset(d_meta = d_trn)
        tst_dataset = customPytorchDatset(d_meta = d_tst)
        
        #..................................................
        # Custom pytorch dataloader
        trn_loader = DataLoader(dataset=trn_dataset,
                                batch_size=batch_size,
                                shuffle=True,)
    
        tst_loader = DataLoader(dataset=tst_dataset,
                                batch_size=batch_size,
                                shuffle=False,)
        
        #_________________________________________________________________
        model = []
        model = vanilla2DCNN_v1(in_channels,
                               num_classes,).to(device)
        
        #_________________________________________________________________
        optimizer = optim.Adam(model.parameters(), lr=lr)
        
        #_________________________________________________________________
        print(f"\n__________________\nTraining foldID: {foldID}")
        trn_rslts, tst_rslts = train(model=model,
                                     trn_loader=trn_loader,
                                     tst_loader=tst_loader,
                                     optimizer=optimizer,
                                     weights=weights,
                                     epochs=epochs,
                                     arch_id=arch_id,
                                     foldID=foldID,
                                     track_train_id=track_train_id,
                                     to_save_root=cfg.ROOT_TO_SAVE_RESLT,
                                     verbose_epo_steps=verbose ,
                                     save_model=save_model
                                    )
        #_________________________________________________________________
        # Free memory
        model.cpu()
        del model, 
        del trn_dataset, tst_dataset
        del trn_loader, tst_loader
        gc.collect()
        torch.cuda.empty_cache()
        gc.collect()
        torch.cuda.empty_cache()
        gc.collect()
    
        #_________________________________________________________________
        # break # Loop across folds
    #_________________________________________________________________
    # break # Loop across seeds
#______________________________________________________________________
# Out:
# _____________________________
# Training for seed: 0
#
# __________________
# Training foldID: seed0_fold0
# Epo: 0 | tr_loss: 2.1904 | tr_acc: 0.3870 | tst_loss: 0.9009 | tst_acc: 0.7104 |tst_ba: 0.2619 |tst_f1: 0.4822 |tst_pr: 0.5009 |tst_rc: 0.5079 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0532 | tr_acc: 0.9977 | tst_loss: 0.8908 | tst_acc: 0.8054 |tst_ba: 0.5899 |tst_f1: 0.7089 |tst_pr: 0.7083 |tst_rc: 0.7266 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0154 | tr_acc: 0.9977 | tst_loss: 0.9183 | tst_acc: 0.7964 |tst_ba: 0.5421 |tst_f1: 0.6891 |tst_pr: 0.6953 |tst_rc: 0.6948 |lr: 0.001000 |
#
# __________________
# Training foldID: seed0_fold1
# Epo: 0 | tr_loss: 1.9228 | tr_acc: 0.3770 | tst_loss: 1.0250 | tst_acc: 0.4840 |tst_ba: 0.0840 |tst_f1: 0.3320 |tst_pr: 0.3773 |tst_rc: 0.3893 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0554 | tr_acc: 0.9897 | tst_loss: 0.7768 | tst_acc: 0.7626 |tst_ba: 0.3898 |tst_f1: 0.5907 |tst_pr: 0.6078 |tst_rc: 0.5932 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0085 | tr_acc: 1.0000 | tst_loss: 0.8045 | tst_acc: 0.8082 |tst_ba: 0.5007 |tst_f1: 0.6765 |tst_pr: 0.7291 |tst_rc: 0.6671 |lr: 0.001000 |
#
# __________________
# Training foldID: seed0_fold2
# Epo: 0 | tr_loss: 2.4745 | tr_acc: 0.3724 | tst_loss: 1.0686 | tst_acc: 0.5114 |tst_ba: 0.0000 |tst_f1: 0.2256 |tst_pr: 0.1705 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0743 | tr_acc: 0.9863 | tst_loss: 0.4095 | tst_acc: 0.8493 |tst_ba: 0.6383 |tst_f1: 0.7487 |tst_pr: 0.7499 |tst_rc: 0.7589 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0149 | tr_acc: 0.9966 | tst_loss: 0.4815 | tst_acc: 0.8219 |tst_ba: 0.5577 |tst_f1: 0.7026 |tst_pr: 0.7133 |tst_rc: 0.7052 |lr: 0.001000 |
#
# __________________
# Training foldID: seed0_fold3
# Epo: 0 | tr_loss: 3.1430 | tr_acc: 0.4362 | tst_loss: 1.2455 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0961 | tr_acc: 0.9909 | tst_loss: 0.8298 | tst_acc: 0.6256 |tst_ba: 0.3930 |tst_f1: 0.5619 |tst_pr: 0.5924 |tst_rc: 0.5954 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0215 | tr_acc: 1.0000 | tst_loss: 1.1111 | tst_acc: 0.6301 |tst_ba: 0.4100 |tst_f1: 0.5779 |tst_pr: 0.6018 |tst_rc: 0.6067 |lr: 0.001000 |
#
# __________________
# Training foldID: seed0_fold4
# Epo: 0 | tr_loss: 1.8072 | tr_acc: 0.4021 | tst_loss: 1.1804 | tst_acc: 0.1598 |tst_ba: -0.2743 |tst_f1: 0.1655 |tst_pr: 0.2009 |tst_rc: 0.1504 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0819 | tr_acc: 0.9772 | tst_loss: 0.7344 | tst_acc: 0.8174 |tst_ba: 0.4582 |tst_f1: 0.6226 |tst_pr: 0.7269 |tst_rc: 0.6388 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0176 | tr_acc: 0.9977 | tst_loss: 0.6884 | tst_acc: 0.8082 |tst_ba: 0.5942 |tst_f1: 0.7232 |tst_pr: 0.7243 |tst_rc: 0.7295 |lr: 0.001000 |
# _____________________________
# Training for seed: 1
#
# __________________
# Training foldID: seed1_fold0
# Epo: 0 | tr_loss: 2.0494 | tr_acc: 0.3459 | tst_loss: 1.0348 | tst_acc: 0.4887 |tst_ba: 0.0741 |tst_f1: 0.3902 |tst_pr: 0.4175 |tst_rc: 0.3827 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0354 | tr_acc: 0.9943 | tst_loss: 1.1781 | tst_acc: 0.6380 |tst_ba: 0.2766 |tst_f1: 0.5207 |tst_pr: 0.5491 |tst_rc: 0.5177 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0052 | tr_acc: 1.0000 | tst_loss: 1.2732 | tst_acc: 0.6878 |tst_ba: 0.3329 |tst_f1: 0.5542 |tst_pr: 0.5663 |tst_rc: 0.5553 |lr: 0.001000 |
#
# __________________
# Training foldID: seed1_fold1
# Epo: 0 | tr_loss: 4.0818 | tr_acc: 0.3440 | tst_loss: 0.9004 | tst_acc: 0.5114 |tst_ba: 0.0000 |tst_f1: 0.2256 |tst_pr: 0.1705 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1183 | tr_acc: 0.9692 | tst_loss: 0.5444 | tst_acc: 0.8676 |tst_ba: 0.5369 |tst_f1: 0.6952 |tst_pr: 0.8021 |tst_rc: 0.6913 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0165 | tr_acc: 0.9966 | tst_loss: 1.2343 | tst_acc: 0.6895 |tst_ba: 0.3862 |tst_f1: 0.5648 |tst_pr: 0.6558 |tst_rc: 0.5908 |lr: 0.001000 |
#
# __________________
# Training foldID: seed1_fold2
# Epo: 0 | tr_loss: 4.2082 | tr_acc: 0.3018 | tst_loss: 1.4854 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0918 | tr_acc: 0.9852 | tst_loss: 0.9536 | tst_acc: 0.6575 |tst_ba: 0.3362 |tst_f1: 0.5350 |tst_pr: 0.6101 |tst_rc: 0.5575 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0418 | tr_acc: 0.9897 | tst_loss: 2.3416 | tst_acc: 0.5708 |tst_ba: 0.2530 |tst_f1: 0.4769 |tst_pr: 0.8230 |tst_rc: 0.5020 |lr: 0.001000 |
#
# __________________
# Training foldID: seed1_fold3
# Epo: 0 | tr_loss: 1.8741 | tr_acc: 0.3235 | tst_loss: 1.0543 | tst_acc: 0.4840 |tst_ba: 0.0621 |tst_f1: 0.3520 |tst_pr: 0.3578 |tst_rc: 0.3747 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0566 | tr_acc: 0.9897 | tst_loss: 1.2990 | tst_acc: 0.7854 |tst_ba: 0.4776 |tst_f1: 0.6417 |tst_pr: 0.6597 |tst_rc: 0.6517 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0108 | tr_acc: 0.9954 | tst_loss: 1.3835 | tst_acc: 0.8493 |tst_ba: 0.5385 |tst_f1: 0.6904 |tst_pr: 0.7146 |tst_rc: 0.6924 |lr: 0.001000 |
#
# __________________
# Training foldID: seed1_fold4
# Epo: 0 | tr_loss: 2.1682 | tr_acc: 0.4487 | tst_loss: 1.2541 | tst_acc: 0.1644 |tst_ba: 0.0723 |tst_f1: 0.1535 |tst_pr: 0.3720 |tst_rc: 0.3815 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1224 | tr_acc: 0.9761 | tst_loss: 0.7521 | tst_acc: 0.6758 |tst_ba: 0.4492 |tst_f1: 0.6044 |tst_pr: 0.6084 |tst_rc: 0.6328 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0401 | tr_acc: 0.9966 | tst_loss: 0.9077 | tst_acc: 0.6758 |tst_ba: 0.4390 |tst_f1: 0.6591 |tst_pr: 0.7310 |tst_rc: 0.6260 |lr: 0.001000 |
# _____________________________
# Training for seed: 2
#
# __________________
# Training foldID: seed2_fold0
# Epo: 0 | tr_loss: 2.6773 | tr_acc: 0.3493 | tst_loss: 1.0942 | tst_acc: 0.4751 |tst_ba: 0.0043 |tst_f1: 0.3120 |tst_pr: 0.2996 |tst_rc: 0.3362 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0663 | tr_acc: 0.9874 | tst_loss: 1.0919 | tst_acc: 0.6923 |tst_ba: 0.3892 |tst_f1: 0.5862 |tst_pr: 0.5859 |tst_rc: 0.5928 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0052 | tr_acc: 1.0000 | tst_loss: 1.3251 | tst_acc: 0.7285 |tst_ba: 0.5128 |tst_f1: 0.6508 |tst_pr: 0.6464 |tst_rc: 0.6752 |lr: 0.001000 |
#
# __________________
# Training foldID: seed2_fold1
# Epo: 0 | tr_loss: 2.9016 | tr_acc: 0.2825 | tst_loss: 1.1239 | tst_acc: 0.1370 |tst_ba: -0.1712 |tst_f1: 0.1197 |tst_pr: 0.0961 |tst_rc: 0.2192 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0994 | tr_acc: 0.9784 | tst_loss: 1.1218 | tst_acc: 0.5662 |tst_ba: 0.2859 |tst_f1: 0.5080 |tst_pr: 0.5480 |tst_rc: 0.5239 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0082 | tr_acc: 1.0000 | tst_loss: 0.7851 | tst_acc: 0.8037 |tst_ba: 0.5648 |tst_f1: 0.7241 |tst_pr: 0.7701 |tst_rc: 0.7099 |lr: 0.001000 |
#
# __________________
# Training foldID: seed2_fold2
# Epo: 0 | tr_loss: 1.5287 | tr_acc: 0.4396 | tst_loss: 0.8765 | tst_acc: 0.6895 |tst_ba: 0.2989 |tst_f1: 0.4884 |tst_pr: 0.5037 |tst_rc: 0.5326 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0390 | tr_acc: 0.9920 | tst_loss: 0.6813 | tst_acc: 0.8447 |tst_ba: 0.6455 |tst_f1: 0.7785 |tst_pr: 0.8237 |tst_rc: 0.7637 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0316 | tr_acc: 0.9943 | tst_loss: 0.7988 | tst_acc: 0.8082 |tst_ba: 0.4641 |tst_f1: 0.6353 |tst_pr: 0.7462 |tst_rc: 0.6427 |lr: 0.001000 |
#
# __________________
# Training foldID: seed2_fold3
# Epo: 0 | tr_loss: 1.9313 | tr_acc: 0.3724 | tst_loss: 0.9730 | tst_acc: 0.6484 |tst_ba: 0.1901 |tst_f1: 0.4286 |tst_pr: 0.4222 |tst_rc: 0.4601 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0282 | tr_acc: 0.9966 | tst_loss: 1.1877 | tst_acc: 0.7443 |tst_ba: 0.4117 |tst_f1: 0.6038 |tst_pr: 0.6610 |tst_rc: 0.6078 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0197 | tr_acc: 0.9954 | tst_loss: 0.8547 | tst_acc: 0.7991 |tst_ba: 0.5315 |tst_f1: 0.6832 |tst_pr: 0.6809 |tst_rc: 0.6877 |lr: 0.001000 |
#
# __________________
# Training foldID: seed2_fold4
# Epo: 0 | tr_loss: 2.7152 | tr_acc: 0.4544 | tst_loss: 1.1912 | tst_acc: 0.2694 |tst_ba: -0.1446 |tst_f1: 0.1632 |tst_pr: 0.1245 |tst_rc: 0.2369 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0608 | tr_acc: 0.9841 | tst_loss: 1.0617 | tst_acc: 0.6849 |tst_ba: 0.3451 |tst_f1: 0.5615 |tst_pr: 0.5675 |tst_rc: 0.5634 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0217 | tr_acc: 0.9943 | tst_loss: 1.1639 | tst_acc: 0.6393 |tst_ba: 0.2911 |tst_f1: 0.5283 |tst_pr: 0.5442 |tst_rc: 0.5274 |lr: 0.001000 |
# _____________________________
# Training for seed: 3
#
# __________________
# Training foldID: seed3_fold0
# Epo: 0 | tr_loss: 2.4452 | tr_acc: 0.4543 | tst_loss: 0.9931 | tst_acc: 0.5113 |tst_ba: 0.0000 |tst_f1: 0.2255 |tst_pr: 0.1704 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0196 | tr_acc: 0.9954 | tst_loss: 0.4349 | tst_acc: 0.8054 |tst_ba: 0.4796 |tst_f1: 0.6526 |tst_pr: 0.6644 |tst_rc: 0.6531 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0030 | tr_acc: 1.0000 | tst_loss: 0.3818 | tst_acc: 0.8688 |tst_ba: 0.5538 |tst_f1: 0.7111 |tst_pr: 0.8187 |tst_rc: 0.7025 |lr: 0.001000 |
#
# __________________
# Training foldID: seed3_fold1
# Epo: 0 | tr_loss: 1.4424 | tr_acc: 0.4613 | tst_loss: 1.1722 | tst_acc: 0.2466 |tst_ba: 0.1480 |tst_f1: 0.2443 |tst_pr: 0.6073 |tst_rc: 0.4320 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0193 | tr_acc: 0.9943 | tst_loss: 1.1439 | tst_acc: 0.6712 |tst_ba: 0.5804 |tst_f1: 0.7123 |tst_pr: 0.8452 |tst_rc: 0.7202 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0119 | tr_acc: 0.9943 | tst_loss: 0.6932 | tst_acc: 0.8128 |tst_ba: 0.7172 |tst_f1: 0.7751 |tst_pr: 0.7754 |tst_rc: 0.8115 |lr: 0.001000 |
#
# __________________
# Training foldID: seed3_fold2
# Epo: 0 | tr_loss: 1.2195 | tr_acc: 0.6002 | tst_loss: 1.1063 | tst_acc: 0.3242 |tst_ba: 0.1498 |tst_f1: 0.3452 |tst_pr: 0.6305 |tst_rc: 0.4332 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0243 | tr_acc: 0.9977 | tst_loss: 0.2948 | tst_acc: 0.9315 |tst_ba: 0.7764 |tst_f1: 0.8667 |tst_pr: 0.8891 |tst_rc: 0.8509 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0200 | tr_acc: 0.9932 | tst_loss: 0.3384 | tst_acc: 0.8904 |tst_ba: 0.7221 |tst_f1: 0.8163 |tst_pr: 0.8191 |tst_rc: 0.8148 |lr: 0.001000 |
#
# __________________
# Training foldID: seed3_fold3
# Epo: 0 | tr_loss: 2.6621 | tr_acc: 0.4100 | tst_loss: 1.2268 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0718 | tr_acc: 0.9875 | tst_loss: 0.8894 | tst_acc: 0.6256 |tst_ba: 0.2894 |tst_f1: 0.5255 |tst_pr: 0.5425 |tst_rc: 0.5262 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0285 | tr_acc: 0.9977 | tst_loss: 0.8984 | tst_acc: 0.6895 |tst_ba: 0.3597 |tst_f1: 0.5727 |tst_pr: 0.5749 |tst_rc: 0.5731 |lr: 0.001000 |
#
# __________________
# Training foldID: seed3_fold4
# Epo: 0 | tr_loss: 3.1109 | tr_acc: 0.4226 | tst_loss: 1.0345 | tst_acc: 0.5799 |tst_ba: 0.1200 |tst_f1: 0.3723 |tst_pr: 0.5969 |tst_rc: 0.4133 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0182 | tr_acc: 0.9989 | tst_loss: 1.5972 | tst_acc: 0.6301 |tst_ba: 0.2260 |tst_f1: 0.4883 |tst_pr: 0.4959 |tst_rc: 0.4840 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0017 | tr_acc: 1.0000 | tst_loss: 2.0691 | tst_acc: 0.6667 |tst_ba: 0.2695 |tst_f1: 0.5125 |tst_pr: 0.5125 |tst_rc: 0.5130 |lr: 0.001000 |
# _____________________________
# Training for seed: 4
#
# __________________
# Training foldID: seed4_fold0
# Epo: 0 | tr_loss: 1.7922 | tr_acc: 0.4338 | tst_loss: 1.2648 | tst_acc: 0.2579 |tst_ba: -0.1607 |tst_f1: 0.1367 |tst_pr: 0.0979 |tst_rc: 0.2262 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0223 | tr_acc: 0.9977 | tst_loss: 0.6344 | tst_acc: 0.6471 |tst_ba: 0.2950 |tst_f1: 0.5170 |tst_pr: 0.5733 |tst_rc: 0.5300 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0031 | tr_acc: 1.0000 | tst_loss: 0.4245 | tst_acc: 0.8462 |tst_ba: 0.4928 |tst_f1: 0.6564 |tst_pr: 0.6973 |tst_rc: 0.6618 |lr: 0.001000 |
#
# __________________
# Training foldID: seed4_fold1
# Epo: 0 | tr_loss: 1.5976 | tr_acc: 0.5057 | tst_loss: 0.9559 | tst_acc: 0.4977 |tst_ba: 0.3702 |tst_f1: 0.4743 |tst_pr: 0.5268 |tst_rc: 0.5801 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0202 | tr_acc: 0.9966 | tst_loss: 1.0559 | tst_acc: 0.6895 |tst_ba: 0.5982 |tst_f1: 0.6906 |tst_pr: 0.7576 |tst_rc: 0.7321 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0112 | tr_acc: 0.9966 | tst_loss: 1.0835 | tst_acc: 0.6849 |tst_ba: 0.5922 |tst_f1: 0.6773 |tst_pr: 0.7355 |tst_rc: 0.7281 |lr: 0.001000 |
#
# __________________
# Training foldID: seed4_fold2
# Epo: 0 | tr_loss: 1.9785 | tr_acc: 0.4328 | tst_loss: 1.0941 | tst_acc: 0.4795 |tst_ba: 0.2634 |tst_f1: 0.3516 |tst_pr: 0.2803 |tst_rc: 0.5089 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0417 | tr_acc: 0.9943 | tst_loss: 0.4663 | tst_acc: 0.8584 |tst_ba: 0.6815 |tst_f1: 0.7734 |tst_pr: 0.7686 |tst_rc: 0.7877 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0148 | tr_acc: 0.9966 | tst_loss: 0.5972 | tst_acc: 0.9041 |tst_ba: 0.7480 |tst_f1: 0.8408 |tst_pr: 0.8518 |tst_rc: 0.8320 |lr: 0.001000 |
#
# __________________
# Training foldID: seed4_fold3
# Epo: 0 | tr_loss: 1.4868 | tr_acc: 0.5171 | tst_loss: 1.1818 | tst_acc: 0.3242 |tst_ba: -0.0364 |tst_f1: 0.2612 |tst_pr: 0.3461 |tst_rc: 0.3090 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0517 | tr_acc: 0.9875 | tst_loss: 1.1486 | tst_acc: 0.6347 |tst_ba: 0.2866 |tst_f1: 0.5230 |tst_pr: 0.5300 |tst_rc: 0.5244 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0035 | tr_acc: 1.0000 | tst_loss: 1.3599 | tst_acc: 0.6621 |tst_ba: 0.4108 |tst_f1: 0.5857 |tst_pr: 0.5833 |tst_rc: 0.6072 |lr: 0.001000 |
#
# __________________
# Training foldID: seed4_fold4
# Epo: 0 | tr_loss: 1.8172 | tr_acc: 0.3200 | tst_loss: 0.9641 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0202 | tr_acc: 0.9977 | tst_loss: 1.2002 | tst_acc: 0.7169 |tst_ba: 0.3249 |tst_f1: 0.5589 |tst_pr: 0.5730 |tst_rc: 0.5499 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0003 | tr_acc: 1.0000 | tst_loss: 1.8096 | tst_acc: 0.7352 |tst_ba: 0.3521 |tst_f1: 0.5719 |tst_pr: 0.5772 |tst_rc: 0.5681 |lr: 0.001000 |
# _____________________________
# Training for seed: 5
#
# __________________
# Training foldID: seed5_fold0
# Epo: 0 | tr_loss: 3.0115 | tr_acc: 0.3938 | tst_loss: 1.0613 | tst_acc: 0.4299 |tst_ba: 0.1364 |tst_f1: 0.3554 |tst_pr: 0.6181 |tst_rc: 0.4243 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0619 | tr_acc: 0.9863 | tst_loss: 0.3270 | tst_acc: 0.9140 |tst_ba: 0.7530 |tst_f1: 0.8568 |tst_pr: 0.8889 |tst_rc: 0.8353 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0164 | tr_acc: 0.9977 | tst_loss: 0.2895 | tst_acc: 0.9276 |tst_ba: 0.7754 |tst_f1: 0.8825 |tst_pr: 0.9448 |tst_rc: 0.8503 |lr: 0.001000 |
#
# __________________
# Training foldID: seed5_fold1
# Epo: 0 | tr_loss: 2.5618 | tr_acc: 0.4066 | tst_loss: 1.1107 | tst_acc: 0.4749 |tst_ba: 0.1709 |tst_f1: 0.3752 |tst_pr: 0.5648 |tst_rc: 0.4473 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0652 | tr_acc: 0.9897 | tst_loss: 1.4505 | tst_acc: 0.4612 |tst_ba: 0.0998 |tst_f1: 0.3940 |tst_pr: 0.4102 |tst_rc: 0.3999 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0177 | tr_acc: 0.9966 | tst_loss: 2.3191 | tst_acc: 0.4201 |tst_ba: 0.1898 |tst_f1: 0.4010 |tst_pr: 0.4544 |tst_rc: 0.4599 |lr: 0.001000 |
#
# __________________
# Training foldID: seed5_fold2
# Epo: 0 | tr_loss: 2.4956 | tr_acc: 0.4112 | tst_loss: 1.0063 | tst_acc: 0.4932 |tst_ba: 0.0126 |tst_f1: 0.3050 |tst_pr: 0.3269 |tst_rc: 0.3417 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0360 | tr_acc: 0.9932 | tst_loss: 1.3280 | tst_acc: 0.6575 |tst_ba: 0.2419 |tst_f1: 0.5014 |tst_pr: 0.5273 |tst_rc: 0.4946 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0040 | tr_acc: 1.0000 | tst_loss: 1.6996 | tst_acc: 0.6941 |tst_ba: 0.3025 |tst_f1: 0.5411 |tst_pr: 0.5500 |tst_rc: 0.5350 |lr: 0.001000 |
#
# __________________
# Training foldID: seed5_fold3
# Epo: 0 | tr_loss: 2.2861 | tr_acc: 0.3633 | tst_loss: 0.9847 | tst_acc: 0.5571 |tst_ba: 0.1343 |tst_f1: 0.3634 |tst_pr: 0.6320 |tst_rc: 0.4229 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0208 | tr_acc: 0.9989 | tst_loss: 0.4753 | tst_acc: 0.7991 |tst_ba: 0.4863 |tst_f1: 0.6601 |tst_pr: 0.7335 |tst_rc: 0.6575 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0035 | tr_acc: 1.0000 | tst_loss: 0.5433 | tst_acc: 0.8037 |tst_ba: 0.5235 |tst_f1: 0.6922 |tst_pr: 0.7669 |tst_rc: 0.6823 |lr: 0.001000 |
#
# __________________
# Training foldID: seed5_fold4
# Epo: 0 | tr_loss: 2.9515 | tr_acc: 0.3690 | tst_loss: 1.1051 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.3069 | tr_acc: 0.9510 | tst_loss: 0.5676 | tst_acc: 0.8493 |tst_ba: 0.6913 |tst_f1: 0.8111 |tst_pr: 0.8345 |tst_rc: 0.7942 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0531 | tr_acc: 0.9954 | tst_loss: 0.4247 | tst_acc: 0.8904 |tst_ba: 0.7783 |tst_f1: 0.8689 |tst_pr: 0.9066 |tst_rc: 0.8522 |lr: 0.001000 |
# _____________________________
# Training for seed: 6
#
# __________________
# Training foldID: seed6_fold0
# Epo: 0 | tr_loss: 2.0007 | tr_acc: 0.3596 | tst_loss: 0.9343 | tst_acc: 0.5294 |tst_ba: 0.0880 |tst_f1: 0.3689 |tst_pr: 0.3492 |tst_rc: 0.3920 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0555 | tr_acc: 0.9954 | tst_loss: 1.1889 | tst_acc: 0.5792 |tst_ba: 0.2286 |tst_f1: 0.4786 |tst_pr: 0.5126 |tst_rc: 0.4857 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0167 | tr_acc: 0.9966 | tst_loss: 1.3722 | tst_acc: 0.5385 |tst_ba: 0.1846 |tst_f1: 0.4546 |tst_pr: 0.4713 |tst_rc: 0.4564 |lr: 0.001000 |
#
# __________________
# Training foldID: seed6_fold1
# Epo: 0 | tr_loss: 3.5907 | tr_acc: 0.2984 | tst_loss: 1.0685 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.2193 | tr_acc: 0.9362 | tst_loss: 1.7749 | tst_acc: 0.5114 |tst_ba: 0.1177 |tst_f1: 0.4277 |tst_pr: 0.4897 |tst_rc: 0.4118 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0417 | tr_acc: 0.9943 | tst_loss: 1.8850 | tst_acc: 0.5479 |tst_ba: 0.1347 |tst_f1: 0.4516 |tst_pr: 0.5070 |tst_rc: 0.4232 |lr: 0.001000 |
#
# __________________
# Training foldID: seed6_fold2
# Epo: 0 | tr_loss: 1.6030 | tr_acc: 0.4761 | tst_loss: 1.0876 | tst_acc: 0.2785 |tst_ba: 0.1808 |tst_f1: 0.2773 |tst_pr: 0.6780 |tst_rc: 0.4539 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0047 | tr_acc: 1.0000 | tst_loss: 1.0840 | tst_acc: 0.7078 |tst_ba: 0.4118 |tst_f1: 0.6017 |tst_pr: 0.6590 |tst_rc: 0.6079 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0010 | tr_acc: 1.0000 | tst_loss: 1.1024 | tst_acc: 0.7352 |tst_ba: 0.4386 |tst_f1: 0.6231 |tst_pr: 0.6766 |tst_rc: 0.6258 |lr: 0.001000 |
#
# __________________
# Training foldID: seed6_fold3
# Epo: 0 | tr_loss: 3.0129 | tr_acc: 0.3052 | tst_loss: 1.0324 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0896 | tr_acc: 0.9818 | tst_loss: 0.2520 | tst_acc: 0.9452 |tst_ba: 0.7648 |tst_f1: 0.8786 |tst_pr: 0.9603 |tst_rc: 0.8432 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0107 | tr_acc: 0.9977 | tst_loss: 0.1772 | tst_acc: 0.9680 |tst_ba: 0.8690 |tst_f1: 0.9397 |tst_pr: 0.9790 |tst_rc: 0.9127 |lr: 0.001000 |
#
# __________________
# Training foldID: seed6_fold4
# Epo: 0 | tr_loss: 2.3971 | tr_acc: 0.3223 | tst_loss: 1.1011 | tst_acc: 0.3516 |tst_ba: 0.0652 |tst_f1: 0.3054 |tst_pr: 0.4698 |tst_rc: 0.3768 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0534 | tr_acc: 0.9886 | tst_loss: 0.5127 | tst_acc: 0.7991 |tst_ba: 0.6219 |tst_f1: 0.7197 |tst_pr: 0.7124 |tst_rc: 0.7480 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0127 | tr_acc: 0.9977 | tst_loss: 0.4811 | tst_acc: 0.8995 |tst_ba: 0.7022 |tst_f1: 0.8337 |tst_pr: 0.9277 |tst_rc: 0.8015 |lr: 0.001000 |
# _____________________________
# Training for seed: 7
#
# __________________
# Training foldID: seed7_fold0
# Epo: 0 | tr_loss: 1.6649 | tr_acc: 0.3973 | tst_loss: 1.0384 | tst_acc: 0.6652 |tst_ba: 0.3272 |tst_f1: 0.5488 |tst_pr: 0.5587 |tst_rc: 0.5515 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0308 | tr_acc: 0.9943 | tst_loss: 1.2145 | tst_acc: 0.5973 |tst_ba: 0.2612 |tst_f1: 0.4911 |tst_pr: 0.5670 |tst_rc: 0.5075 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0180 | tr_acc: 0.9954 | tst_loss: 0.9592 | tst_acc: 0.7059 |tst_ba: 0.3598 |tst_f1: 0.5687 |tst_pr: 0.5790 |tst_rc: 0.5732 |lr: 0.001000 |
#
# __________________
# Training foldID: seed7_fold1
# Epo: 0 | tr_loss: 1.2451 | tr_acc: 0.4544 | tst_loss: 0.9067 | tst_acc: 0.7352 |tst_ba: 0.3988 |tst_f1: 0.5923 |tst_pr: 0.6041 |tst_rc: 0.5992 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0322 | tr_acc: 0.9920 | tst_loss: 0.4356 | tst_acc: 0.8995 |tst_ba: 0.5713 |tst_f1: 0.7191 |tst_pr: 0.9281 |tst_rc: 0.7142 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0179 | tr_acc: 0.9966 | tst_loss: 0.2758 | tst_acc: 0.8767 |tst_ba: 0.6004 |tst_f1: 0.7412 |tst_pr: 0.7571 |tst_rc: 0.7336 |lr: 0.001000 |
#
# __________________
# Training foldID: seed7_fold2
# Epo: 0 | tr_loss: 2.6135 | tr_acc: 0.4282 | tst_loss: 1.4920 | tst_acc: 0.0913 |tst_ba: -0.1722 |tst_f1: 0.0815 |tst_pr: 0.1480 |tst_rc: 0.2185 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0471 | tr_acc: 0.9920 | tst_loss: 1.1995 | tst_acc: 0.7489 |tst_ba: 0.4357 |tst_f1: 0.6291 |tst_pr: 0.7584 |tst_rc: 0.6238 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0118 | tr_acc: 0.9966 | tst_loss: 1.4472 | tst_acc: 0.7991 |tst_ba: 0.4816 |tst_f1: 0.6677 |tst_pr: 0.8678 |tst_rc: 0.6544 |lr: 0.001000 |
#
# __________________
# Training foldID: seed7_fold3
# Epo: 0 | tr_loss: 2.5709 | tr_acc: 0.3622 | tst_loss: 1.0542 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0942 | tr_acc: 0.9806 | tst_loss: 0.8004 | tst_acc: 0.6667 |tst_ba: 0.4605 |tst_f1: 0.6106 |tst_pr: 0.6126 |tst_rc: 0.6403 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0496 | tr_acc: 0.9886 | tst_loss: 0.9333 | tst_acc: 0.6712 |tst_ba: 0.4798 |tst_f1: 0.6184 |tst_pr: 0.6156 |tst_rc: 0.6532 |lr: 0.001000 |
#
# __________________
# Training foldID: seed7_fold4
# Epo: 0 | tr_loss: 1.8828 | tr_acc: 0.4271 | tst_loss: 1.1379 | tst_acc: 0.3562 |tst_ba: 0.0945 |tst_f1: 0.3378 |tst_pr: 0.4981 |tst_rc: 0.3964 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0144 | tr_acc: 0.9989 | tst_loss: 1.1884 | tst_acc: 0.7123 |tst_ba: 0.3586 |tst_f1: 0.5790 |tst_pr: 0.5989 |tst_rc: 0.5724 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0020 | tr_acc: 1.0000 | tst_loss: 1.0494 | tst_acc: 0.7763 |tst_ba: 0.4274 |tst_f1: 0.6188 |tst_pr: 0.6414 |tst_rc: 0.6182 |lr: 0.001000 |
# _____________________________
# Training for seed: 8
#
# __________________
# Training foldID: seed8_fold0
# Epo: 0 | tr_loss: 3.0566 | tr_acc: 0.4703 | tst_loss: 0.9777 | tst_acc: 0.6606 |tst_ba: 0.1964 |tst_f1: 0.4331 |tst_pr: 0.4776 |tst_rc: 0.4643 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0474 | tr_acc: 0.9920 | tst_loss: 0.6275 | tst_acc: 0.7376 |tst_ba: 0.4182 |tst_f1: 0.6035 |tst_pr: 0.6260 |tst_rc: 0.6121 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0054 | tr_acc: 1.0000 | tst_loss: 0.5105 | tst_acc: 0.8507 |tst_ba: 0.4854 |tst_f1: 0.6430 |tst_pr: 0.6747 |tst_rc: 0.6569 |lr: 0.001000 |
#
# __________________
# Training foldID: seed8_fold1
# Epo: 0 | tr_loss: 2.2102 | tr_acc: 0.5273 | tst_loss: 1.1216 | tst_acc: 0.1918 |tst_ba: -0.0179 |tst_f1: 0.1644 |tst_pr: 0.2335 |tst_rc: 0.3214 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0442 | tr_acc: 0.9909 | tst_loss: 1.2992 | tst_acc: 0.5936 |tst_ba: 0.4359 |tst_f1: 0.6072 |tst_pr: 0.7857 |tst_rc: 0.6239 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0238 | tr_acc: 0.9943 | tst_loss: 0.8621 | tst_acc: 0.6986 |tst_ba: 0.5931 |tst_f1: 0.7289 |tst_pr: 0.7817 |tst_rc: 0.7287 |lr: 0.001000 |
#
# __________________
# Training foldID: seed8_fold2
# Epo: 0 | tr_loss: 3.0034 | tr_acc: 0.3770 | tst_loss: 0.9710 | tst_acc: 0.5297 |tst_ba: 0.1380 |tst_f1: 0.3653 |tst_pr: 0.4364 |tst_rc: 0.4253 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1268 | tr_acc: 0.9681 | tst_loss: 0.4854 | tst_acc: 0.8493 |tst_ba: 0.6110 |tst_f1: 0.7391 |tst_pr: 0.7406 |tst_rc: 0.7407 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0341 | tr_acc: 0.9920 | tst_loss: 0.4816 | tst_acc: 0.8721 |tst_ba: 0.7246 |tst_f1: 0.8187 |tst_pr: 0.8319 |tst_rc: 0.8164 |lr: 0.001000 |
#
# __________________
# Training foldID: seed8_fold3
# Epo: 0 | tr_loss: 2.1121 | tr_acc: 0.3998 | tst_loss: 1.0819 | tst_acc: 0.4155 |tst_ba: 0.0357 |tst_f1: 0.2327 |tst_pr: 0.4645 |tst_rc: 0.3571 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0767 | tr_acc: 0.9875 | tst_loss: 0.7069 | tst_acc: 0.6667 |tst_ba: 0.2898 |tst_f1: 0.5268 |tst_pr: 0.5378 |tst_rc: 0.5265 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0276 | tr_acc: 1.0000 | tst_loss: 0.8206 | tst_acc: 0.6621 |tst_ba: 0.3150 |tst_f1: 0.5437 |tst_pr: 0.5536 |tst_rc: 0.5433 |lr: 0.001000 |
#
# __________________
# Training foldID: seed8_fold4
# Epo: 0 | tr_loss: 1.7110 | tr_acc: 0.4009 | tst_loss: 0.8622 | tst_acc: 0.6119 |tst_ba: 0.1621 |tst_f1: 0.4169 |tst_pr: 0.5826 |tst_rc: 0.4414 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0058 | tr_acc: 1.0000 | tst_loss: 1.3321 | tst_acc: 0.7397 |tst_ba: 0.3581 |tst_f1: 0.5753 |tst_pr: 0.5798 |tst_rc: 0.5721 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0011 | tr_acc: 1.0000 | tst_loss: 1.5302 | tst_acc: 0.7717 |tst_ba: 0.3894 |tst_f1: 0.5958 |tst_pr: 0.6000 |tst_rc: 0.5929 |lr: 0.001000 |
# _____________________________
# Training for seed: 9
#
# __________________
# Training foldID: seed9_fold0
# Epo: 0 | tr_loss: 1.5774 | tr_acc: 0.4429 | tst_loss: 1.1864 | tst_acc: 0.2036 |tst_ba: 0.0929 |tst_f1: 0.1759 |tst_pr: 0.3733 |tst_rc: 0.3953 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0327 | tr_acc: 0.9909 | tst_loss: 0.3932 | tst_acc: 0.8824 |tst_ba: 0.6060 |tst_f1: 0.7486 |tst_pr: 0.8073 |tst_rc: 0.7373 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0096 | tr_acc: 0.9977 | tst_loss: 0.3221 | tst_acc: 0.8959 |tst_ba: 0.6685 |tst_f1: 0.7957 |tst_pr: 0.8419 |tst_rc: 0.7790 |lr: 0.001000 |
#
# __________________
# Training foldID: seed9_fold1
# Epo: 0 | tr_loss: 1.6392 | tr_acc: 0.5171 | tst_loss: 1.0263 | tst_acc: 0.6164 |tst_ba: 0.2430 |tst_f1: 0.4831 |tst_pr: 0.7723 |tst_rc: 0.4954 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0423 | tr_acc: 0.9909 | tst_loss: 1.1747 | tst_acc: 0.5845 |tst_ba: 0.2796 |tst_f1: 0.5079 |tst_pr: 0.8103 |tst_rc: 0.5197 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0081 | tr_acc: 1.0000 | tst_loss: 0.9100 | tst_acc: 0.6667 |tst_ba: 0.5174 |tst_f1: 0.6919 |tst_pr: 0.8116 |tst_rc: 0.6783 |lr: 0.001000 |
#
# __________________
# Training foldID: seed9_fold2
# Epo: 0 | tr_loss: 2.3368 | tr_acc: 0.3850 | tst_loss: 0.9669 | tst_acc: 0.5662 |tst_ba: 0.1830 |tst_f1: 0.3907 |tst_pr: 0.4888 |tst_rc: 0.4554 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0416 | tr_acc: 0.9897 | tst_loss: 1.6214 | tst_acc: 0.5571 |tst_ba: 0.3206 |tst_f1: 0.4971 |tst_pr: 0.5317 |tst_rc: 0.5471 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0345 | tr_acc: 0.9920 | tst_loss: 1.3707 | tst_acc: 0.6804 |tst_ba: 0.3967 |tst_f1: 0.6260 |tst_pr: 0.6967 |tst_rc: 0.5978 |lr: 0.001000 |
#
# __________________
# Training foldID: seed9_fold3
# Epo: 0 | tr_loss: 2.5680 | tr_acc: 0.3815 | tst_loss: 1.1160 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0893 | tr_acc: 0.9852 | tst_loss: 0.9701 | tst_acc: 0.6438 |tst_ba: 0.2378 |tst_f1: 0.5067 |tst_pr: 0.5326 |tst_rc: 0.4919 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0128 | tr_acc: 0.9989 | tst_loss: 0.7603 | tst_acc: 0.8128 |tst_ba: 0.4716 |tst_f1: 0.6479 |tst_pr: 0.6482 |tst_rc: 0.6478 |lr: 0.001000 |
#
# __________________
# Training foldID: seed9_fold4
# Epo: 0 | tr_loss: 3.0827 | tr_acc: 0.3793 | tst_loss: 1.0523 | tst_acc: 0.5160 |tst_ba: 0.2314 |tst_f1: 0.4436 |tst_pr: 0.5436 |tst_rc: 0.4876 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0551 | tr_acc: 0.9932 | tst_loss: 1.2306 | tst_acc: 0.5297 |tst_ba: 0.4411 |tst_f1: 0.5074 |tst_pr: 0.5920 |tst_rc: 0.6274 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0146 | tr_acc: 0.9966 | tst_loss: 1.1937 | tst_acc: 0.5571 |tst_ba: 0.3760 |tst_f1: 0.5212 |tst_pr: 0.5835 |tst_rc: 0.5840 |lr: 0.001000 |
# _____________________________
# Training for seed: 10
#
# __________________
# Training foldID: seed10_fold0
# Epo: 0 | tr_loss: 3.1145 | tr_acc: 0.3390 | tst_loss: 1.1576 | tst_acc: 0.1086 |tst_ba: 0.0000 |tst_f1: 0.0653 |tst_pr: 0.0362 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0950 | tr_acc: 0.9897 | tst_loss: 0.5876 | tst_acc: 0.6923 |tst_ba: 0.6525 |tst_f1: 0.7200 |tst_pr: 0.7464 |tst_rc: 0.7684 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0235 | tr_acc: 0.9977 | tst_loss: 0.7007 | tst_acc: 0.7195 |tst_ba: 0.6898 |tst_f1: 0.7601 |tst_pr: 0.8116 |tst_rc: 0.7932 |lr: 0.001000 |
#
# __________________
# Training foldID: seed10_fold1
# Epo: 0 | tr_loss: 1.6158 | tr_acc: 0.4226 | tst_loss: 1.0782 | tst_acc: 0.5708 |tst_ba: 0.1727 |tst_f1: 0.4568 |tst_pr: 0.5029 |tst_rc: 0.4484 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0503 | tr_acc: 0.9909 | tst_loss: 1.6678 | tst_acc: 0.6712 |tst_ba: 0.2701 |tst_f1: 0.5138 |tst_pr: 0.5633 |tst_rc: 0.5134 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0188 | tr_acc: 0.9977 | tst_loss: 1.8398 | tst_acc: 0.6119 |tst_ba: 0.2167 |tst_f1: 0.4866 |tst_pr: 0.5091 |tst_rc: 0.4778 |lr: 0.001000 |
#
# __________________
# Training foldID: seed10_fold2
# Epo: 0 | tr_loss: 2.0667 | tr_acc: 0.3690 | tst_loss: 1.1406 | tst_acc: 0.2374 |tst_ba: 0.1086 |tst_f1: 0.2058 |tst_pr: 0.3258 |tst_rc: 0.4058 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0433 | tr_acc: 0.9954 | tst_loss: 1.4013 | tst_acc: 0.5753 |tst_ba: 0.2005 |tst_f1: 0.4788 |tst_pr: 0.5183 |tst_rc: 0.4670 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0063 | tr_acc: 1.0000 | tst_loss: 1.4961 | tst_acc: 0.6438 |tst_ba: 0.2675 |tst_f1: 0.5114 |tst_pr: 0.5237 |tst_rc: 0.5116 |lr: 0.001000 |
#
# __________________
# Training foldID: seed10_fold3
# Epo: 0 | tr_loss: 1.1981 | tr_acc: 0.5786 | tst_loss: 0.9048 | tst_acc: 0.5708 |tst_ba: 0.4073 |tst_f1: 0.5413 |tst_pr: 0.6745 |tst_rc: 0.6048 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0056 | tr_acc: 1.0000 | tst_loss: 0.7304 | tst_acc: 0.8219 |tst_ba: 0.5616 |tst_f1: 0.7007 |tst_pr: 0.6988 |tst_rc: 0.7078 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0008 | tr_acc: 1.0000 | tst_loss: 0.8502 | tst_acc: 0.8219 |tst_ba: 0.5764 |tst_f1: 0.7069 |tst_pr: 0.7063 |tst_rc: 0.7176 |lr: 0.001000 |
#
# __________________
# Training foldID: seed10_fold4
# Epo: 0 | tr_loss: 1.8265 | tr_acc: 0.4453 | tst_loss: 0.9570 | tst_acc: 0.5982 |tst_ba: 0.2587 |tst_f1: 0.4854 |tst_pr: 0.8087 |tst_rc: 0.5058 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0243 | tr_acc: 0.9989 | tst_loss: 0.2124 | tst_acc: 0.9498 |tst_ba: 0.8020 |tst_f1: 0.8961 |tst_pr: 0.9456 |tst_rc: 0.8680 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0120 | tr_acc: 0.9977 | tst_loss: 0.3327 | tst_acc: 0.9132 |tst_ba: 0.6860 |tst_f1: 0.8226 |tst_pr: 0.9374 |tst_rc: 0.7907 |lr: 0.001000 |
# _____________________________
# Training for seed: 11
#
# __________________
# Training foldID: seed11_fold0
# Epo: 0 | tr_loss: 1.4051 | tr_acc: 0.3938 | tst_loss: 0.8936 | tst_acc: 0.6018 |tst_ba: 0.2168 |tst_f1: 0.4204 |tst_pr: 0.4961 |tst_rc: 0.4779 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0497 | tr_acc: 0.9909 | tst_loss: 0.2038 | tst_acc: 0.9548 |tst_ba: 0.8065 |tst_f1: 0.9052 |tst_pr: 0.9689 |tst_rc: 0.8710 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0208 | tr_acc: 0.9977 | tst_loss: 0.1952 | tst_acc: 0.9638 |tst_ba: 0.8333 |tst_f1: 0.9193 |tst_pr: 0.9727 |tst_rc: 0.8889 |lr: 0.001000 |
#
# __________________
# Training foldID: seed11_fold1
# Epo: 0 | tr_loss: 1.9860 | tr_acc: 0.4043 | tst_loss: 1.1071 | tst_acc: 0.4475 |tst_ba: 0.1776 |tst_f1: 0.4129 |tst_pr: 0.4469 |tst_rc: 0.4517 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0690 | tr_acc: 0.9841 | tst_loss: 0.6681 | tst_acc: 0.7534 |tst_ba: 0.5040 |tst_f1: 0.6918 |tst_pr: 0.8168 |tst_rc: 0.6694 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0178 | tr_acc: 0.9989 | tst_loss: 0.8485 | tst_acc: 0.7534 |tst_ba: 0.6022 |tst_f1: 0.7278 |tst_pr: 0.7572 |tst_rc: 0.7348 |lr: 0.001000 |
#
# __________________
# Training foldID: seed11_fold2
# Epo: 0 | tr_loss: 2.8738 | tr_acc: 0.3610 | tst_loss: 1.2406 | tst_acc: 0.3836 |tst_ba: 0.0208 |tst_f1: 0.2105 |tst_pr: 0.4602 |tst_rc: 0.3472 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0689 | tr_acc: 0.9795 | tst_loss: 0.9677 | tst_acc: 0.6895 |tst_ba: 0.4041 |tst_f1: 0.6116 |tst_pr: 0.6248 |tst_rc: 0.6027 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0103 | tr_acc: 0.9989 | tst_loss: 1.2823 | tst_acc: 0.6530 |tst_ba: 0.4315 |tst_f1: 0.5834 |tst_pr: 0.5842 |tst_rc: 0.6210 |lr: 0.001000 |
#
# __________________
# Training foldID: seed11_fold3
# Epo: 0 | tr_loss: 2.2588 | tr_acc: 0.3485 | tst_loss: 0.9017 | tst_acc: 0.8128 |tst_ba: 0.3992 |tst_f1: 0.5715 |tst_pr: 0.5460 |tst_rc: 0.5994 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0221 | tr_acc: 0.9977 | tst_loss: 0.7731 | tst_acc: 0.7169 |tst_ba: 0.4192 |tst_f1: 0.5884 |tst_pr: 0.6136 |tst_rc: 0.6128 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0023 | tr_acc: 1.0000 | tst_loss: 0.8484 | tst_acc: 0.8037 |tst_ba: 0.5056 |tst_f1: 0.6707 |tst_pr: 0.6737 |tst_rc: 0.6704 |lr: 0.001000 |
#
# __________________
# Training foldID: seed11_fold4
# Epo: 0 | tr_loss: 3.0339 | tr_acc: 0.3166 | tst_loss: 1.0000 | tst_acc: 0.3836 |tst_ba: -0.0673 |tst_f1: 0.2701 |tst_pr: 0.2618 |tst_rc: 0.2885 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0316 | tr_acc: 0.9920 | tst_loss: 0.8606 | tst_acc: 0.7260 |tst_ba: 0.4905 |tst_f1: 0.6581 |tst_pr: 0.6881 |tst_rc: 0.6603 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0114 | tr_acc: 0.9989 | tst_loss: 1.0957 | tst_acc: 0.7078 |tst_ba: 0.4773 |tst_f1: 0.6358 |tst_pr: 0.6648 |tst_rc: 0.6515 |lr: 0.001000 |
# _____________________________
# Training for seed: 12
#
# __________________
# Training foldID: seed12_fold0
# Epo: 0 | tr_loss: 2.7009 | tr_acc: 0.3584 | tst_loss: 0.9643 | tst_acc: 0.8009 |tst_ba: 0.4569 |tst_f1: 0.6503 |tst_pr: 0.7112 |tst_rc: 0.6379 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0308 | tr_acc: 0.9954 | tst_loss: 0.2526 | tst_acc: 0.9186 |tst_ba: 0.6742 |tst_f1: 0.8117 |tst_pr: 0.9412 |tst_rc: 0.7828 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0422 | tr_acc: 0.9897 | tst_loss: 0.2617 | tst_acc: 0.8959 |tst_ba: 0.6521 |tst_f1: 0.7961 |tst_pr: 0.9283 |tst_rc: 0.7681 |lr: 0.001000 |
#
# __________________
# Training foldID: seed12_fold1
# Epo: 0 | tr_loss: 1.3991 | tr_acc: 0.4305 | tst_loss: 1.1839 | tst_acc: 0.3014 |tst_ba: 0.0184 |tst_f1: 0.2632 |tst_pr: 0.5148 |tst_rc: 0.3456 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0377 | tr_acc: 0.9943 | tst_loss: 0.5762 | tst_acc: 0.7260 |tst_ba: 0.5388 |tst_f1: 0.6463 |tst_pr: 0.6486 |tst_rc: 0.6925 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0802 | tr_acc: 0.9818 | tst_loss: 1.1495 | tst_acc: 0.6667 |tst_ba: 0.4239 |tst_f1: 0.6316 |tst_pr: 0.8278 |tst_rc: 0.6159 |lr: 0.001000 |
#
# __________________
# Training foldID: seed12_fold2
# Epo: 0 | tr_loss: 2.1041 | tr_acc: 0.4112 | tst_loss: 1.0519 | tst_acc: 0.4521 |tst_ba: 0.1954 |tst_f1: 0.4115 |tst_pr: 0.5894 |tst_rc: 0.4636 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0504 | tr_acc: 0.9875 | tst_loss: 1.0314 | tst_acc: 0.6438 |tst_ba: 0.3618 |tst_f1: 0.5589 |tst_pr: 0.5613 |tst_rc: 0.5745 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0331 | tr_acc: 0.9932 | tst_loss: 1.3125 | tst_acc: 0.6393 |tst_ba: 0.4173 |tst_f1: 0.5826 |tst_pr: 0.6006 |tst_rc: 0.6116 |lr: 0.001000 |
#
# __________________
# Training foldID: seed12_fold3
# Epo: 0 | tr_loss: 1.4475 | tr_acc: 0.5421 | tst_loss: 1.0797 | tst_acc: 0.5708 |tst_ba: 0.4182 |tst_f1: 0.4198 |tst_pr: 0.3743 |tst_rc: 0.6121 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0310 | tr_acc: 0.9954 | tst_loss: 0.8714 | tst_acc: 0.7078 |tst_ba: 0.3736 |tst_f1: 0.5789 |tst_pr: 0.5948 |tst_rc: 0.5824 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0014 | tr_acc: 1.0000 | tst_loss: 0.8540 | tst_acc: 0.8584 |tst_ba: 0.5662 |tst_f1: 0.7168 |tst_pr: 0.7340 |tst_rc: 0.7108 |lr: 0.001000 |
#
# __________________
# Training foldID: seed12_fold4
# Epo: 0 | tr_loss: 1.8706 | tr_acc: 0.4465 | tst_loss: 1.2124 | tst_acc: 0.2374 |tst_ba: -0.0238 |tst_f1: 0.1933 |tst_pr: 0.1471 |tst_rc: 0.3174 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0232 | tr_acc: 0.9954 | tst_loss: 0.6860 | tst_acc: 0.7169 |tst_ba: 0.4488 |tst_f1: 0.6176 |tst_pr: 0.6396 |tst_rc: 0.6326 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0236 | tr_acc: 0.9966 | tst_loss: 0.9273 | tst_acc: 0.6484 |tst_ba: 0.3390 |tst_f1: 0.5522 |tst_pr: 0.6873 |tst_rc: 0.5593 |lr: 0.001000 |
# _____________________________
# Training for seed: 13
#
# __________________
# Training foldID: seed13_fold0
# Epo: 0 | tr_loss: 2.3325 | tr_acc: 0.3082 | tst_loss: 1.0542 | tst_acc: 0.4615 |tst_ba: -0.0487 |tst_f1: 0.2105 |tst_pr: 0.1619 |tst_rc: 0.3009 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0843 | tr_acc: 0.9817 | tst_loss: 0.4784 | tst_acc: 0.8009 |tst_ba: 0.4588 |tst_f1: 0.6382 |tst_pr: 0.6610 |tst_rc: 0.6392 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0183 | tr_acc: 0.9977 | tst_loss: 0.4579 | tst_acc: 0.8190 |tst_ba: 0.5231 |tst_f1: 0.6936 |tst_pr: 0.8086 |tst_rc: 0.6820 |lr: 0.001000 |
#
# __________________
# Training foldID: seed13_fold1
# Epo: 0 | tr_loss: 2.1892 | tr_acc: 0.3462 | tst_loss: 1.1184 | tst_acc: 0.3516 |tst_ba: 0.2086 |tst_f1: 0.3358 |tst_pr: 0.4608 |tst_rc: 0.4724 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0836 | tr_acc: 0.9875 | tst_loss: 0.4630 | tst_acc: 0.8767 |tst_ba: 0.7579 |tst_f1: 0.8459 |tst_pr: 0.8615 |tst_rc: 0.8386 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0215 | tr_acc: 0.9977 | tst_loss: 0.6980 | tst_acc: 0.6895 |tst_ba: 0.5491 |tst_f1: 0.6648 |tst_pr: 0.7160 |tst_rc: 0.6994 |lr: 0.001000 |
#
# __________________
# Training foldID: seed13_fold2
# Epo: 0 | tr_loss: 2.1598 | tr_acc: 0.3588 | tst_loss: 1.3991 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0675 | tr_acc: 0.9875 | tst_loss: 0.5176 | tst_acc: 0.8676 |tst_ba: 0.6375 |tst_f1: 0.7920 |tst_pr: 0.8779 |tst_rc: 0.7583 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0228 | tr_acc: 0.9943 | tst_loss: 0.4420 | tst_acc: 0.8721 |tst_ba: 0.6996 |tst_f1: 0.8326 |tst_pr: 0.8905 |tst_rc: 0.7997 |lr: 0.001000 |
#
# __________________
# Training foldID: seed13_fold3
# Epo: 0 | tr_loss: 1.8731 | tr_acc: 0.4556 | tst_loss: 1.0545 | tst_acc: 0.4429 |tst_ba: 0.1427 |tst_f1: 0.4065 |tst_pr: 0.4241 |tst_rc: 0.4285 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0260 | tr_acc: 0.9954 | tst_loss: 0.8977 | tst_acc: 0.6393 |tst_ba: 0.4205 |tst_f1: 0.5957 |tst_pr: 0.5956 |tst_rc: 0.6136 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0219 | tr_acc: 0.9954 | tst_loss: 1.3030 | tst_acc: 0.6119 |tst_ba: 0.3945 |tst_f1: 0.5794 |tst_pr: 0.6241 |tst_rc: 0.5963 |lr: 0.001000 |
#
# __________________
# Training foldID: seed13_fold4
# Epo: 0 | tr_loss: 2.1620 | tr_acc: 0.4487 | tst_loss: 1.1624 | tst_acc: 0.2831 |tst_ba: -0.0314 |tst_f1: 0.2831 |tst_pr: 0.4559 |tst_rc: 0.3124 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0119 | tr_acc: 1.0000 | tst_loss: 1.4638 | tst_acc: 0.5434 |tst_ba: 0.2753 |tst_f1: 0.4947 |tst_pr: 0.5304 |tst_rc: 0.5168 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0022 | tr_acc: 1.0000 | tst_loss: 1.9764 | tst_acc: 0.5388 |tst_ba: 0.2809 |tst_f1: 0.4903 |tst_pr: 0.5279 |tst_rc: 0.5206 |lr: 0.001000 |
# _____________________________
# Training for seed: 14
#
# __________________
# Training foldID: seed14_fold0
# Epo: 0 | tr_loss: 3.2944 | tr_acc: 0.3390 | tst_loss: 1.1530 | tst_acc: 0.2217 |tst_ba: 0.0263 |tst_f1: 0.2387 |tst_pr: 0.5641 |tst_rc: 0.3509 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0307 | tr_acc: 0.9977 | tst_loss: 0.9387 | tst_acc: 0.6652 |tst_ba: 0.3966 |tst_f1: 0.5757 |tst_pr: 0.5898 |tst_rc: 0.5977 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0036 | tr_acc: 1.0000 | tst_loss: 1.3269 | tst_acc: 0.5566 |tst_ba: 0.2519 |tst_f1: 0.4926 |tst_pr: 0.5430 |tst_rc: 0.5013 |lr: 0.001000 |
#
# __________________
# Training foldID: seed14_fold1
# Epo: 0 | tr_loss: 3.8473 | tr_acc: 0.3451 | tst_loss: 0.8695 | tst_acc: 0.6484 |tst_ba: 0.2587 |tst_f1: 0.4582 |tst_pr: 0.4874 |tst_rc: 0.5058 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0383 | tr_acc: 0.9943 | tst_loss: 0.3612 | tst_acc: 0.8813 |tst_ba: 0.6470 |tst_f1: 0.7950 |tst_pr: 0.8879 |tst_rc: 0.7646 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0156 | tr_acc: 0.9966 | tst_loss: 0.4415 | tst_acc: 0.8721 |tst_ba: 0.6396 |tst_f1: 0.7765 |tst_pr: 0.8257 |tst_rc: 0.7597 |lr: 0.001000 |
#
# __________________
# Training foldID: seed14_fold2
# Epo: 0 | tr_loss: 3.2148 | tr_acc: 0.4134 | tst_loss: 1.1175 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0900 | tr_acc: 0.9897 | tst_loss: 1.3180 | tst_acc: 0.6301 |tst_ba: 0.3570 |tst_f1: 0.5476 |tst_pr: 0.6418 |tst_rc: 0.5713 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0267 | tr_acc: 0.9943 | tst_loss: 1.2590 | tst_acc: 0.6210 |tst_ba: 0.2990 |tst_f1: 0.5156 |tst_pr: 0.6861 |tst_rc: 0.5326 |lr: 0.001000 |
#
# __________________
# Training foldID: seed14_fold3
# Epo: 0 | tr_loss: 2.1292 | tr_acc: 0.3964 | tst_loss: 1.1163 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0826 | tr_acc: 0.9795 | tst_loss: 0.4578 | tst_acc: 0.8402 |tst_ba: 0.6559 |tst_f1: 0.7492 |tst_pr: 0.7471 |tst_rc: 0.7706 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0113 | tr_acc: 0.9943 | tst_loss: 0.4096 | tst_acc: 0.9132 |tst_ba: 0.6782 |tst_f1: 0.8193 |tst_pr: 0.9350 |tst_rc: 0.7855 |lr: 0.001000 |
#
# __________________
# Training foldID: seed14_fold4
# Epo: 0 | tr_loss: 2.7617 | tr_acc: 0.3986 | tst_loss: 0.9672 | tst_acc: 0.4749 |tst_ba: 0.0937 |tst_f1: 0.3022 |tst_pr: 0.4731 |tst_rc: 0.3958 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0899 | tr_acc: 0.9841 | tst_loss: 0.8366 | tst_acc: 0.6895 |tst_ba: 0.4610 |tst_f1: 0.6236 |tst_pr: 0.6305 |tst_rc: 0.6407 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0145 | tr_acc: 0.9966 | tst_loss: 1.1025 | tst_acc: 0.6712 |tst_ba: 0.4618 |tst_f1: 0.6141 |tst_pr: 0.6059 |tst_rc: 0.6412 |lr: 0.001000 |
# _____________________________
# Training for seed: 15
#
# __________________
# Training foldID: seed15_fold0
# Epo: 0 | tr_loss: 2.4078 | tr_acc: 0.4304 | tst_loss: 0.9248 | tst_acc: 0.6063 |tst_ba: 0.1250 |tst_f1: 0.3735 |tst_pr: 0.5075 |tst_rc: 0.4167 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0576 | tr_acc: 0.9897 | tst_loss: 0.8883 | tst_acc: 0.7104 |tst_ba: 0.5446 |tst_f1: 0.6031 |tst_pr: 0.6771 |tst_rc: 0.6964 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0087 | tr_acc: 1.0000 | tst_loss: 0.5901 | tst_acc: 0.8416 |tst_ba: 0.5849 |tst_f1: 0.7211 |tst_pr: 0.7201 |tst_rc: 0.7232 |lr: 0.001000 |
#
# __________________
# Training foldID: seed15_fold1
# Epo: 0 | tr_loss: 1.6309 | tr_acc: 0.4465 | tst_loss: 1.1643 | tst_acc: 0.2374 |tst_ba: 0.1242 |tst_f1: 0.2413 |tst_pr: 0.3253 |tst_rc: 0.4162 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0437 | tr_acc: 0.9932 | tst_loss: 1.7536 | tst_acc: 0.5342 |tst_ba: 0.3209 |tst_f1: 0.5149 |tst_pr: 0.6852 |tst_rc: 0.5473 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0091 | tr_acc: 0.9977 | tst_loss: 1.2004 | tst_acc: 0.7626 |tst_ba: 0.5340 |tst_f1: 0.7031 |tst_pr: 0.7938 |tst_rc: 0.6893 |lr: 0.001000 |
#
# __________________
# Training foldID: seed15_fold2
# Epo: 0 | tr_loss: 2.8094 | tr_acc: 0.3656 | tst_loss: 1.0893 | tst_acc: 0.3790 |tst_ba: 0.1668 |tst_f1: 0.3623 |tst_pr: 0.4817 |tst_rc: 0.4445 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0977 | tr_acc: 0.9727 | tst_loss: 0.3561 | tst_acc: 0.8584 |tst_ba: 0.6691 |tst_f1: 0.8135 |tst_pr: 0.8971 |tst_rc: 0.7794 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0195 | tr_acc: 0.9954 | tst_loss: 0.3228 | tst_acc: 0.8767 |tst_ba: 0.8350 |tst_f1: 0.8545 |tst_pr: 0.8346 |tst_rc: 0.8900 |lr: 0.001000 |
#
# __________________
# Training foldID: seed15_fold3
# Epo: 0 | tr_loss: 1.9519 | tr_acc: 0.3656 | tst_loss: 1.0582 | tst_acc: 0.4201 |tst_ba: 0.0402 |tst_f1: 0.2395 |tst_pr: 0.3651 |tst_rc: 0.3601 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0350 | tr_acc: 0.9897 | tst_loss: 1.7023 | tst_acc: 0.6849 |tst_ba: 0.3412 |tst_f1: 0.5553 |tst_pr: 0.5772 |tst_rc: 0.5608 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0082 | tr_acc: 0.9989 | tst_loss: 1.6499 | tst_acc: 0.7397 |tst_ba: 0.3870 |tst_f1: 0.5899 |tst_pr: 0.5899 |tst_rc: 0.5913 |lr: 0.001000 |
#
# __________________
# Training foldID: seed15_fold4
# Epo: 0 | tr_loss: 2.0069 | tr_acc: 0.3770 | tst_loss: 1.0959 | tst_acc: 0.3607 |tst_ba: 0.2401 |tst_f1: 0.3327 |tst_pr: 0.6109 |tst_rc: 0.4934 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0422 | tr_acc: 0.9954 | tst_loss: 1.2938 | tst_acc: 0.5753 |tst_ba: 0.2169 |tst_f1: 0.4742 |tst_pr: 0.4812 |tst_rc: 0.4779 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0078 | tr_acc: 1.0000 | tst_loss: 1.7285 | tst_acc: 0.5479 |tst_ba: 0.1901 |tst_f1: 0.4570 |tst_pr: 0.4691 |tst_rc: 0.4601 |lr: 0.001000 |
# _____________________________
# Training for seed: 16
#
# __________________
# Training foldID: seed16_fold0
# Epo: 0 | tr_loss: 1.7215 | tr_acc: 0.4509 | tst_loss: 0.9598 | tst_acc: 0.6471 |tst_ba: 0.2710 |tst_f1: 0.5006 |tst_pr: 0.5474 |tst_rc: 0.5140 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0616 | tr_acc: 0.9909 | tst_loss: 0.5890 | tst_acc: 0.7828 |tst_ba: 0.6472 |tst_f1: 0.7290 |tst_pr: 0.7309 |tst_rc: 0.7648 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0277 | tr_acc: 0.9943 | tst_loss: 0.5126 | tst_acc: 0.8371 |tst_ba: 0.5557 |tst_f1: 0.7150 |tst_pr: 0.7793 |tst_rc: 0.7038 |lr: 0.001000 |
#
# __________________
# Training foldID: seed16_fold1
# Epo: 0 | tr_loss: 2.2081 | tr_acc: 0.4214 | tst_loss: 1.2483 | tst_acc: 0.1689 |tst_ba: 0.0580 |tst_f1: 0.1387 |tst_pr: 0.3485 |tst_rc: 0.3720 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0451 | tr_acc: 0.9886 | tst_loss: 0.2495 | tst_acc: 0.9087 |tst_ba: 0.8257 |tst_f1: 0.9011 |tst_pr: 0.9328 |tst_rc: 0.8838 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0153 | tr_acc: 0.9954 | tst_loss: 0.1663 | tst_acc: 0.9406 |tst_ba: 0.9061 |tst_f1: 0.9438 |tst_pr: 0.9538 |tst_rc: 0.9374 |lr: 0.001000 |
#
# __________________
# Training foldID: seed16_fold2
# Epo: 0 | tr_loss: 2.9047 | tr_acc: 0.3542 | tst_loss: 1.1760 | tst_acc: 0.1187 |tst_ba: 0.0089 |tst_f1: 0.0781 |tst_pr: 0.3702 |tst_rc: 0.3393 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0829 | tr_acc: 0.9761 | tst_loss: 1.0347 | tst_acc: 0.8311 |tst_ba: 0.5495 |tst_f1: 0.7176 |tst_pr: 0.7646 |tst_rc: 0.6997 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0179 | tr_acc: 0.9977 | tst_loss: 1.8080 | tst_acc: 0.6804 |tst_ba: 0.3422 |tst_f1: 0.5484 |tst_pr: 0.8388 |tst_rc: 0.5615 |lr: 0.001000 |
#
# __________________
# Training foldID: seed16_fold3
# Epo: 0 | tr_loss: 2.2093 | tr_acc: 0.3599 | tst_loss: 1.1202 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0197 | tr_acc: 0.9966 | tst_loss: 2.5968 | tst_acc: 0.4977 |tst_ba: 0.2423 |tst_f1: 0.4596 |tst_pr: 0.4888 |tst_rc: 0.4949 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0014 | tr_acc: 1.0000 | tst_loss: 3.0952 | tst_acc: 0.4658 |tst_ba: 0.1978 |tst_f1: 0.4336 |tst_pr: 0.4749 |tst_rc: 0.4652 |lr: 0.001000 |
#
# __________________
# Training foldID: seed16_fold4
# Epo: 0 | tr_loss: 2.3465 | tr_acc: 0.4294 | tst_loss: 1.0228 | tst_acc: 0.5982 |tst_ba: 0.1145 |tst_f1: 0.3645 |tst_pr: 0.4202 |tst_rc: 0.4096 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0444 | tr_acc: 0.9886 | tst_loss: 0.7456 | tst_acc: 0.7489 |tst_ba: 0.5354 |tst_f1: 0.6421 |tst_pr: 0.6790 |tst_rc: 0.6903 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0072 | tr_acc: 1.0000 | tst_loss: 0.6438 | tst_acc: 0.8402 |tst_ba: 0.5811 |tst_f1: 0.7256 |tst_pr: 0.7380 |tst_rc: 0.7207 |lr: 0.001000 |
# _____________________________
# Training for seed: 17
#
# __________________
# Training foldID: seed17_fold0
# Epo: 0 | tr_loss: 2.4480 | tr_acc: 0.3265 | tst_loss: 1.1075 | tst_acc: 0.1086 |tst_ba: 0.0000 |tst_f1: 0.0653 |tst_pr: 0.0362 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1817 | tr_acc: 0.9623 | tst_loss: 0.7075 | tst_acc: 0.7602 |tst_ba: 0.4617 |tst_f1: 0.6375 |tst_pr: 0.6358 |tst_rc: 0.6411 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0353 | tr_acc: 0.9943 | tst_loss: 0.4683 | tst_acc: 0.8190 |tst_ba: 0.5467 |tst_f1: 0.7012 |tst_pr: 0.7153 |tst_rc: 0.6978 |lr: 0.001000 |
#
# __________________
# Training foldID: seed17_fold1
# Epo: 0 | tr_loss: 1.5400 | tr_acc: 0.4533 | tst_loss: 0.9622 | tst_acc: 0.5799 |tst_ba: 0.2003 |tst_f1: 0.4339 |tst_pr: 0.5074 |tst_rc: 0.4669 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0398 | tr_acc: 0.9909 | tst_loss: 0.8581 | tst_acc: 0.8265 |tst_ba: 0.5092 |tst_f1: 0.6741 |tst_pr: 0.6773 |tst_rc: 0.6728 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0222 | tr_acc: 0.9954 | tst_loss: 1.1423 | tst_acc: 0.8037 |tst_ba: 0.4814 |tst_f1: 0.6669 |tst_pr: 0.8126 |tst_rc: 0.6543 |lr: 0.001000 |
#
# __________________
# Training foldID: seed17_fold2
# Epo: 0 | tr_loss: 2.5032 | tr_acc: 0.3349 | tst_loss: 1.0573 | tst_acc: 0.6895 |tst_ba: 0.3059 |tst_f1: 0.5408 |tst_pr: 0.5908 |tst_rc: 0.5373 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0781 | tr_acc: 0.9829 | tst_loss: 0.6568 | tst_acc: 0.7306 |tst_ba: 0.5331 |tst_f1: 0.6503 |tst_pr: 0.6517 |tst_rc: 0.6888 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0060 | tr_acc: 1.0000 | tst_loss: 1.1423 | tst_acc: 0.6895 |tst_ba: 0.5210 |tst_f1: 0.6244 |tst_pr: 0.6392 |tst_rc: 0.6807 |lr: 0.001000 |
#
# __________________
# Training foldID: seed17_fold3
# Epo: 0 | tr_loss: 3.0069 | tr_acc: 0.4613 | tst_loss: 1.4562 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0156 | tr_acc: 0.9989 | tst_loss: 1.6709 | tst_acc: 0.5616 |tst_ba: 0.2277 |tst_f1: 0.4763 |tst_pr: 0.5470 |tst_rc: 0.4851 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0016 | tr_acc: 1.0000 | tst_loss: 2.1438 | tst_acc: 0.6027 |tst_ba: 0.2819 |tst_f1: 0.5088 |tst_pr: 0.5844 |tst_rc: 0.5213 |lr: 0.001000 |
#
# __________________
# Training foldID: seed17_fold4
# Epo: 0 | tr_loss: 1.9151 | tr_acc: 0.4328 | tst_loss: 0.9882 | tst_acc: 0.6164 |tst_ba: 0.2321 |tst_f1: 0.4327 |tst_pr: 0.4990 |tst_rc: 0.4881 |lr: 0.001000 |
# ...
# Epo: 5 | tr_loss: 0.0532 | tr_acc: 0.9897 | tst_loss: 0.5884 | tst_acc: 0.7783 |tst_ba: 0.6263 |tst_f1: 0.7761 |tst_pr: 0.8580 |tst_rc: 0.7509 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0291 | tr_acc: 0.9932 | tst_loss: 0.5639 | tst_acc: 0.7602 |tst_ba: 0.6174 |tst_f1: 0.7399 |tst_pr: 0.7553 |tst_rc: 0.7449 |lr: 0.001000 |
#
# __________________
# Training foldID: seed94_fold1
# Epo: 0 | tr_loss: 3.3023 | tr_acc: 0.3337 | tst_loss: 1.0165 | tst_acc: 0.5114 |tst_ba: 0.0000 |tst_f1: 0.2256 |tst_pr: 0.1705 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0326 | tr_acc: 0.9932 | tst_loss: 1.3555 | tst_acc: 0.7397 |tst_ba: 0.3176 |tst_f1: 0.5370 |tst_pr: 0.5400 |tst_rc: 0.5450 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0101 | tr_acc: 0.9966 | tst_loss: 1.7678 | tst_acc: 0.7671 |tst_ba: 0.3756 |tst_f1: 0.5626 |tst_pr: 0.6776 |tst_rc: 0.5837 |lr: 0.001000 |
#
# __________________
# Training foldID: seed94_fold2
# Epo: 0 | tr_loss: 2.1753 | tr_acc: 0.3588 | tst_loss: 0.9947 | tst_acc: 0.5845 |tst_ba: 0.4378 |tst_f1: 0.4493 |tst_pr: 0.7061 |tst_rc: 0.6252 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0263 | tr_acc: 0.9977 | tst_loss: 1.2244 | tst_acc: 0.7352 |tst_ba: 0.4823 |tst_f1: 0.6284 |tst_pr: 0.6421 |tst_rc: 0.6548 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0039 | tr_acc: 1.0000 | tst_loss: 1.3166 | tst_acc: 0.7078 |tst_ba: 0.4258 |tst_f1: 0.6015 |tst_pr: 0.6090 |tst_rc: 0.6172 |lr: 0.001000 |
#
# __________________
# Training foldID: seed94_fold3
# Epo: 0 | tr_loss: 3.3276 | tr_acc: 0.4863 | tst_loss: 1.4836 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0173 | tr_acc: 0.9977 | tst_loss: 1.3899 | tst_acc: 0.5114 |tst_ba: 0.2705 |tst_f1: 0.4735 |tst_pr: 0.5368 |tst_rc: 0.5137 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0035 | tr_acc: 1.0000 | tst_loss: 1.4946 | tst_acc: 0.5890 |tst_ba: 0.3418 |tst_f1: 0.5489 |tst_pr: 0.6628 |tst_rc: 0.5612 |lr: 0.001000 |
#
# __________________
# Training foldID: seed94_fold4
# Epo: 0 | tr_loss: 3.8885 | tr_acc: 0.3257 | tst_loss: 1.3214 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0658 |tst_pr: 0.0365 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.3662 | tr_acc: 0.9214 | tst_loss: 0.7242 | tst_acc: 0.6712 |tst_ba: 0.3340 |tst_f1: 0.5549 |tst_pr: 0.5544 |tst_rc: 0.5560 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0411 | tr_acc: 0.9932 | tst_loss: 0.5048 | tst_acc: 0.8402 |tst_ba: 0.5101 |tst_f1: 0.6789 |tst_pr: 0.8263 |tst_rc: 0.6734 |lr: 0.001000 |
# _____________________________
# Training for seed: 95
#
# __________________
# Training foldID: seed95_fold0
# Epo: 0 | tr_loss: 1.9509 | tr_acc: 0.3642 | tst_loss: 1.2263 | tst_acc: 0.3846 |tst_ba: 0.0208 |tst_f1: 0.2109 |tst_pr: 0.4606 |tst_rc: 0.3472 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0508 | tr_acc: 0.9943 | tst_loss: 1.3832 | tst_acc: 0.7783 |tst_ba: 0.4107 |tst_f1: 0.6082 |tst_pr: 0.6159 |tst_rc: 0.6071 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0090 | tr_acc: 0.9977 | tst_loss: 1.7073 | tst_acc: 0.7421 |tst_ba: 0.3707 |tst_f1: 0.5823 |tst_pr: 0.5876 |tst_rc: 0.5805 |lr: 0.001000 |
#
# __________________
# Training foldID: seed95_fold1
# Epo: 0 | tr_loss: 2.1049 | tr_acc: 0.3702 | tst_loss: 0.9236 | tst_acc: 0.5114 |tst_ba: 0.0000 |tst_f1: 0.2256 |tst_pr: 0.1705 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1412 | tr_acc: 0.9636 | tst_loss: 1.3415 | tst_acc: 0.4064 |tst_ba: 0.0431 |tst_f1: 0.3614 |tst_pr: 0.4774 |tst_rc: 0.3621 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0128 | tr_acc: 0.9989 | tst_loss: 0.9871 | tst_acc: 0.6575 |tst_ba: 0.2965 |tst_f1: 0.5359 |tst_pr: 0.5530 |tst_rc: 0.5310 |lr: 0.001000 |
#
# __________________
# Training foldID: seed95_fold2
# Epo: 0 | tr_loss: 2.9908 | tr_acc: 0.3838 | tst_loss: 0.9884 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0314 | tr_acc: 0.9989 | tst_loss: 0.6056 | tst_acc: 0.8082 |tst_ba: 0.5771 |tst_f1: 0.7232 |tst_pr: 0.7587 |tst_rc: 0.7181 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0040 | tr_acc: 1.0000 | tst_loss: 0.4697 | tst_acc: 0.8858 |tst_ba: 0.7169 |tst_f1: 0.8259 |tst_pr: 0.8542 |tst_rc: 0.8113 |lr: 0.001000 |
#
# __________________
# Training foldID: seed95_fold3
# Epo: 0 | tr_loss: 2.7764 | tr_acc: 0.2984 | tst_loss: 1.0569 | tst_acc: 0.3790 |tst_ba: 0.0000 |tst_f1: 0.1832 |tst_pr: 0.1263 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0696 | tr_acc: 0.9943 | tst_loss: 0.5572 | tst_acc: 0.8219 |tst_ba: 0.6606 |tst_f1: 0.7550 |tst_pr: 0.7577 |tst_rc: 0.7738 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0254 | tr_acc: 0.9954 | tst_loss: 0.5210 | tst_acc: 0.8265 |tst_ba: 0.6651 |tst_f1: 0.7606 |tst_pr: 0.7644 |tst_rc: 0.7767 |lr: 0.001000 |
#
# __________________
# Training foldID: seed95_fold4
# Epo: 0 | tr_loss: 3.0894 | tr_acc: 0.4134 | tst_loss: 1.1259 | tst_acc: 0.1096 |tst_ba: 0.0000 |tst_f1: 0.0664 |tst_pr: 0.0369 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0291 | tr_acc: 0.9977 | tst_loss: 0.3057 | tst_acc: 0.8721 |tst_ba: 0.8344 |tst_f1: 0.8245 |tst_pr: 0.8199 |tst_rc: 0.8896 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0160 | tr_acc: 0.9954 | tst_loss: 0.2713 | tst_acc: 0.8721 |tst_ba: 0.8407 |tst_f1: 0.8936 |tst_pr: 0.9136 |tst_rc: 0.8938 |lr: 0.001000 |
# _____________________________
# Training for seed: 96
#
# __________________
# Training foldID: seed96_fold0
# Epo: 0 | tr_loss: 2.2520 | tr_acc: 0.3664 | tst_loss: 0.9990 | tst_acc: 0.5294 |tst_ba: 0.0833 |tst_f1: 0.3235 |tst_pr: 0.5069 |tst_rc: 0.3889 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0687 | tr_acc: 0.9943 | tst_loss: 0.8416 | tst_acc: 0.6425 |tst_ba: 0.5127 |tst_f1: 0.6120 |tst_pr: 0.6522 |tst_rc: 0.6751 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0192 | tr_acc: 0.9954 | tst_loss: 0.7438 | tst_acc: 0.6968 |tst_ba: 0.4185 |tst_f1: 0.6161 |tst_pr: 0.7283 |tst_rc: 0.6123 |lr: 0.001000 |
#
# __________________
# Training foldID: seed96_fold1
# Epo: 0 | tr_loss: 1.6750 | tr_acc: 0.4476 | tst_loss: 1.1493 | tst_acc: 0.1644 |tst_ba: 0.0629 |tst_f1: 0.1481 |tst_pr: 0.6224 |tst_rc: 0.3753 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0863 | tr_acc: 0.9875 | tst_loss: 0.4916 | tst_acc: 0.7763 |tst_ba: 0.7407 |tst_f1: 0.7383 |tst_pr: 0.7345 |tst_rc: 0.8271 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0203 | tr_acc: 0.9966 | tst_loss: 0.2513 | tst_acc: 0.9087 |tst_ba: 0.8195 |tst_f1: 0.9003 |tst_pr: 0.9304 |tst_rc: 0.8797 |lr: 0.001000 |
#
# __________________
# Training foldID: seed96_fold2
# Epo: 0 | tr_loss: 1.7131 | tr_acc: 0.4738 | tst_loss: 1.0598 | tst_acc: 0.5434 |tst_ba: 0.1358 |tst_f1: 0.4019 |tst_pr: 0.4363 |tst_rc: 0.4238 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0170 | tr_acc: 0.9977 | tst_loss: 1.4746 | tst_acc: 0.6256 |tst_ba: 0.4328 |tst_f1: 0.5896 |tst_pr: 0.6242 |tst_rc: 0.6219 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0105 | tr_acc: 0.9977 | tst_loss: 1.9480 | tst_acc: 0.6301 |tst_ba: 0.2674 |tst_f1: 0.4900 |tst_pr: 0.5720 |tst_rc: 0.5116 |lr: 0.001000 |
#
# __________________
# Training foldID: seed96_fold3
# Epo: 0 | tr_loss: 2.1632 | tr_acc: 0.3804 | tst_loss: 1.0514 | tst_acc: 0.5571 |tst_ba: 0.1639 |tst_f1: 0.3619 |tst_pr: 0.6152 |tst_rc: 0.4426 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0211 | tr_acc: 0.9966 | tst_loss: 1.7869 | tst_acc: 0.5205 |tst_ba: 0.2077 |tst_f1: 0.4575 |tst_pr: 0.5198 |tst_rc: 0.4718 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0009 | tr_acc: 1.0000 | tst_loss: 2.0491 | tst_acc: 0.5068 |tst_ba: 0.2232 |tst_f1: 0.4601 |tst_pr: 0.4933 |tst_rc: 0.4821 |lr: 0.001000 |
#
# __________________
# Training foldID: seed96_fold4
# Epo: 0 | tr_loss: 1.3642 | tr_acc: 0.5194 | tst_loss: 1.0480 | tst_acc: 0.4064 |tst_ba: -0.0060 |tst_f1: 0.3688 |tst_pr: 0.4850 |tst_rc: 0.3293 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0122 | tr_acc: 0.9977 | tst_loss: 0.8213 | tst_acc: 0.8174 |tst_ba: 0.6312 |tst_f1: 0.7322 |tst_pr: 0.7261 |tst_rc: 0.7541 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0015 | tr_acc: 1.0000 | tst_loss: 0.8680 | tst_acc: 0.8174 |tst_ba: 0.6149 |tst_f1: 0.7243 |tst_pr: 0.7188 |tst_rc: 0.7432 |lr: 0.001000 |
# _____________________________
# Training for seed: 97
#
# __________________
# Training foldID: seed97_fold0
# Epo: 0 | tr_loss: 3.9273 | tr_acc: 0.3699 | tst_loss: 1.2080 | tst_acc: 0.1493 |tst_ba: -0.2887 |tst_f1: 0.0933 |tst_pr: 0.0698 |tst_rc: 0.1409 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1373 | tr_acc: 0.9715 | tst_loss: 0.8062 | tst_acc: 0.7511 |tst_ba: 0.4986 |tst_f1: 0.6411 |tst_pr: 0.6494 |tst_rc: 0.6658 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0221 | tr_acc: 0.9966 | tst_loss: 0.9186 | tst_acc: 0.6923 |tst_ba: 0.3820 |tst_f1: 0.5826 |tst_pr: 0.5866 |tst_rc: 0.5880 |lr: 0.001000 |
#
# __________________
# Training foldID: seed97_fold1
# Epo: 0 | tr_loss: 2.5677 | tr_acc: 0.4009 | tst_loss: 1.2740 | tst_acc: 0.3653 |tst_ba: 0.0699 |tst_f1: 0.2672 |tst_pr: 0.2458 |tst_rc: 0.3800 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0631 | tr_acc: 0.9897 | tst_loss: 1.2523 | tst_acc: 0.6073 |tst_ba: 0.3783 |tst_f1: 0.5653 |tst_pr: 0.6186 |tst_rc: 0.5855 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0108 | tr_acc: 0.9989 | tst_loss: 1.2613 | tst_acc: 0.6941 |tst_ba: 0.4756 |tst_f1: 0.6466 |tst_pr: 0.6939 |tst_rc: 0.6504 |lr: 0.001000 |
#
# __________________
# Training foldID: seed97_fold2
# Epo: 0 | tr_loss: 1.3730 | tr_acc: 0.3895 | tst_loss: 0.9195 | tst_acc: 0.4977 |tst_ba: 0.0771 |tst_f1: 0.3519 |tst_pr: 0.3589 |tst_rc: 0.3847 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0537 | tr_acc: 0.9875 | tst_loss: 0.1096 | tst_acc: 0.9726 |tst_ba: 0.9194 |tst_f1: 0.9613 |tst_pr: 0.9793 |tst_rc: 0.9463 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0274 | tr_acc: 0.9920 | tst_loss: 0.0923 | tst_acc: 0.9772 |tst_ba: 0.9699 |tst_f1: 0.9824 |tst_pr: 0.9858 |tst_rc: 0.9799 |lr: 0.001000 |
#
# __________________
# Training foldID: seed97_fold3
# Epo: 0 | tr_loss: 2.0621 | tr_acc: 0.4487 | tst_loss: 1.0418 | tst_acc: 0.6073 |tst_ba: 0.2217 |tst_f1: 0.4374 |tst_pr: 0.4685 |tst_rc: 0.4811 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0664 | tr_acc: 0.9852 | tst_loss: 1.4305 | tst_acc: 0.7489 |tst_ba: 0.4271 |tst_f1: 0.6172 |tst_pr: 0.8671 |tst_rc: 0.6181 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0167 | tr_acc: 0.9932 | tst_loss: 1.6066 | tst_acc: 0.8539 |tst_ba: 0.5118 |tst_f1: 0.6692 |tst_pr: 0.9043 |tst_rc: 0.6746 |lr: 0.001000 |
#
# __________________
# Training foldID: seed97_fold4
# Epo: 0 | tr_loss: 1.7660 | tr_acc: 0.4613 | tst_loss: 1.2581 | tst_acc: 0.2648 |tst_ba: 0.1518 |tst_f1: 0.2311 |tst_pr: 0.3673 |tst_rc: 0.4345 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0185 | tr_acc: 1.0000 | tst_loss: 1.0743 | tst_acc: 0.5662 |tst_ba: 0.2843 |tst_f1: 0.5069 |tst_pr: 0.5294 |tst_rc: 0.5229 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0031 | tr_acc: 1.0000 | tst_loss: 1.4000 | tst_acc: 0.5297 |tst_ba: 0.2634 |tst_f1: 0.4837 |tst_pr: 0.5147 |tst_rc: 0.5090 |lr: 0.001000 |
# _____________________________
# Training for seed: 98
#
# __________________
# Training foldID: seed98_fold0
# Epo: 0 | tr_loss: 2.1445 | tr_acc: 0.3276 | tst_loss: 1.1341 | tst_acc: 0.3982 |tst_ba: 0.0833 |tst_f1: 0.2559 |tst_pr: 0.2013 |tst_rc: 0.3889 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0448 | tr_acc: 0.9932 | tst_loss: 1.6805 | tst_acc: 0.5520 |tst_ba: 0.2292 |tst_f1: 0.4574 |tst_pr: 0.6764 |tst_rc: 0.4861 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0135 | tr_acc: 0.9954 | tst_loss: 1.1344 | tst_acc: 0.6878 |tst_ba: 0.4543 |tst_f1: 0.6197 |tst_pr: 0.6631 |tst_rc: 0.6362 |lr: 0.001000 |
#
# __________________
# Training foldID: seed98_fold1
# Epo: 0 | tr_loss: 2.4541 | tr_acc: 0.3998 | tst_loss: 0.9728 | tst_acc: 0.6119 |tst_ba: 0.3578 |tst_f1: 0.5446 |tst_pr: 0.7697 |tst_rc: 0.5719 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.1010 | tr_acc: 0.9863 | tst_loss: 0.4367 | tst_acc: 0.7717 |tst_ba: 0.4829 |tst_f1: 0.6587 |tst_pr: 0.6908 |tst_rc: 0.6553 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0311 | tr_acc: 0.9943 | tst_loss: 0.2417 | tst_acc: 0.9041 |tst_ba: 0.6576 |tst_f1: 0.8012 |tst_pr: 0.9306 |tst_rc: 0.7717 |lr: 0.001000 |
#
# __________________
# Training foldID: seed98_fold2
# Epo: 0 | tr_loss: 2.3768 | tr_acc: 0.3907 | tst_loss: 1.2296 | tst_acc: 0.1461 |tst_ba: -0.0789 |tst_f1: 0.1244 |tst_pr: 0.2147 |tst_rc: 0.2808 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0838 | tr_acc: 0.9795 | tst_loss: 1.3763 | tst_acc: 0.7215 |tst_ba: 0.3372 |tst_f1: 0.5332 |tst_pr: 0.8212 |tst_rc: 0.5581 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0232 | tr_acc: 0.9966 | tst_loss: 1.7307 | tst_acc: 0.5890 |tst_ba: 0.2420 |tst_f1: 0.4716 |tst_pr: 0.5525 |tst_rc: 0.4947 |lr: 0.001000 |
#
# __________________
# Training foldID: seed98_fold3
# Epo: 0 | tr_loss: 2.4270 | tr_acc: 0.3394 | tst_loss: 0.9850 | tst_acc: 0.6438 |tst_ba: 0.2589 |tst_f1: 0.4538 |tst_pr: 0.5006 |tst_rc: 0.5060 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0165 | tr_acc: 1.0000 | tst_loss: 1.0486 | tst_acc: 0.6530 |tst_ba: 0.3621 |tst_f1: 0.5636 |tst_pr: 0.5723 |tst_rc: 0.5748 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0022 | tr_acc: 1.0000 | tst_loss: 1.3842 | tst_acc: 0.6484 |tst_ba: 0.3725 |tst_f1: 0.5657 |tst_pr: 0.5751 |tst_rc: 0.5817 |lr: 0.001000 |
#
# __________________
# Training foldID: seed98_fold4
# Epo: 0 | tr_loss: 1.3806 | tr_acc: 0.4487 | tst_loss: 1.0780 | tst_acc: 0.4201 |tst_ba: 0.2724 |tst_f1: 0.3427 |tst_pr: 0.3842 |tst_rc: 0.5149 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0250 | tr_acc: 0.9989 | tst_loss: 0.8265 | tst_acc: 0.7580 |tst_ba: 0.5474 |tst_f1: 0.6523 |tst_pr: 0.6889 |tst_rc: 0.6983 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0017 | tr_acc: 1.0000 | tst_loss: 0.7687 | tst_acc: 0.8676 |tst_ba: 0.5767 |tst_f1: 0.7447 |tst_pr: 0.9034 |tst_rc: 0.7178 |lr: 0.001000 |
# _____________________________
# Training for seed: 99
#
# __________________
# Training foldID: seed99_fold0
# Epo: 0 | tr_loss: 2.4205 | tr_acc: 0.4132 | tst_loss: 1.4274 | tst_acc: 0.1086 |tst_ba: 0.0000 |tst_f1: 0.0653 |tst_pr: 0.0362 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0490 | tr_acc: 0.9943 | tst_loss: 0.5507 | tst_acc: 0.8190 |tst_ba: 0.6097 |tst_f1: 0.7579 |tst_pr: 0.8350 |tst_rc: 0.7398 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0173 | tr_acc: 0.9977 | tst_loss: 0.7669 | tst_acc: 0.7873 |tst_ba: 0.5951 |tst_f1: 0.7451 |tst_pr: 0.8248 |tst_rc: 0.7301 |lr: 0.001000 |
#
# __________________
# Training foldID: seed99_fold1
# Epo: 0 | tr_loss: 2.0616 | tr_acc: 0.3998 | tst_loss: 0.9910 | tst_acc: 0.6210 |tst_ba: 0.3909 |tst_f1: 0.5610 |tst_pr: 0.5912 |tst_rc: 0.5939 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0565 | tr_acc: 0.9920 | tst_loss: 0.2422 | tst_acc: 0.9087 |tst_ba: 0.7883 |tst_f1: 0.8856 |tst_pr: 0.9309 |tst_rc: 0.8589 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0237 | tr_acc: 0.9966 | tst_loss: 0.2282 | tst_acc: 0.9087 |tst_ba: 0.7883 |tst_f1: 0.8856 |tst_pr: 0.9309 |tst_rc: 0.8589 |lr: 0.001000 |
#
# __________________
# Training foldID: seed99_fold2
# Epo: 0 | tr_loss: 2.2425 | tr_acc: 0.3360 | tst_loss: 1.0288 | tst_acc: 0.5114 |tst_ba: 0.0000 |tst_f1: 0.2256 |tst_pr: 0.1705 |tst_rc: 0.3333 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0550 | tr_acc: 0.9897 | tst_loss: 2.0897 | tst_acc: 0.6027 |tst_ba: 0.2328 |tst_f1: 0.4958 |tst_pr: 0.5367 |tst_rc: 0.4885 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0294 | tr_acc: 0.9943 | tst_loss: 2.3576 | tst_acc: 0.5479 |tst_ba: 0.1698 |tst_f1: 0.4466 |tst_pr: 0.4492 |tst_rc: 0.4465 |lr: 0.001000 |
#
# __________________
# Training foldID: seed99_fold3
# Epo: 0 | tr_loss: 1.6606 | tr_acc: 0.5262 | tst_loss: 1.1417 | tst_acc: 0.1553 |tst_ba: 0.0524 |tst_f1: 0.1343 |tst_pr: 0.4541 |tst_rc: 0.3683 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0243 | tr_acc: 1.0000 | tst_loss: 1.7779 | tst_acc: 0.6073 |tst_ba: 0.2411 |tst_f1: 0.4797 |tst_pr: 0.5180 |tst_rc: 0.4941 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0026 | tr_acc: 1.0000 | tst_loss: 1.8340 | tst_acc: 0.6712 |tst_ba: 0.3106 |tst_f1: 0.5326 |tst_pr: 0.5409 |tst_rc: 0.5404 |lr: 0.001000 |
#
# __________________
# Training foldID: seed99_fold4
# Epo: 0 | tr_loss: 2.4477 | tr_acc: 0.3519 | tst_loss: 1.1195 | tst_acc: 0.3699 |tst_ba: -0.0276 |tst_f1: 0.2237 |tst_pr: 0.4535 |tst_rc: 0.3149 |lr: 0.001000 |
# Epo: 5 | tr_loss: 0.0243 | tr_acc: 0.9954 | tst_loss: 0.9671 | tst_acc: 0.7215 |tst_ba: 0.4229 |tst_f1: 0.6265 |tst_pr: 0.6746 |tst_rc: 0.6153 |lr: 0.001000 |
# Epo: 9 | tr_loss: 0.0010 | tr_acc: 1.0000 | tst_loss: 1.4882 | tst_acc: 0.7443 |tst_ba: 0.4663 |tst_f1: 0.6464 |tst_pr: 0.6697 |tst_rc: 0.6442 |lr: 0.001000 |
# CPU times: user 12h 5min 35s, sys: 26min 56s, total: 12h 32min 31s
# Wall time: 2h 12min 45s
